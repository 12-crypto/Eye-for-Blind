# %% [markdown]
# # EYE FOR BLIND
# Prepared by: Dhruv Rathee
#
# **Problem statement:** To create a deep learning model that can explain the content of an image in the form of speech through caption generation with the attention mechanism on the Flickr8K data set
#
# This type of model is a use case for blind people so that they can understand any image with the help of speech. The caption generated through a CNN-RNN model will be converted to speech using a text-to-speech library.
#
#
#
# This problem statement is an application of both deep learning and natural language processing. The features of an image will be extracted by the CNN-based encoder, and this will be decoded by an RNN model.

# %%
#Import all the required libraries

#System libraries
import os, time
from tqdm import tqdm
import glob

# Data manipulation
import numpy as np
import pandas as pd
import collections, random, re
from collections import Counter

# Model building 
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle


#Read/Display  images
from skimage import io
import matplotlib.pyplot as plt
from PIL import Image
from nltk.translate.bleu_score import sentence_bleu
from nltk.translate.bleu_score import SmoothingFunction

# import tensorflow libraries
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Model
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.utils import plot_model

# %%
print("Tensorflow Version:",tf.__version__)
print("Keras Version     :",keras.__version__)
# Out:
# Tensorflow Version: 2.4.1
# Keras Version     : 2.4.0

# %%
## Global Variables
INPUT_PATH = "../input/flickr8k/"
IMAGE_PATH = INPUT_PATH+'Images/'
CAPTIONS_FILE = INPUT_PATH+'captions.txt'
OUTPUT_IMAGE_PATH = "../working/Image/"

# %% [markdown]
# Let's read the dataset

# %% [markdown]
# ## Data understanding
# 1.Import the dataset and read image & captions into two seperate variables
#
# 2.Visualise both the images & text present in the dataset
#
# 3.Create word-to-index and index-to-word mappings.
#
# 4.Create a dataframe which summarizes the image, path & captions as a dataframe
#
# 5.Visualise the top 30 occuring words in the captions
#
# 6.Create a list which contains all the captions & path

# %%
#Import the dataset and read the image into a seperate variable
all_imgs = glob.glob(IMAGE_PATH + '/*.jpg',recursive=True)
print("The total images present in the dataset: {}".format(len(all_imgs)))
# Out:
# The total images present in the dataset: 8091

# %%
# function to plot read and plot images
def plot_image(images, caption = None, cmap = None):
    f, axes = plt.subplots(1, len(images), sharey = True)
    f.set_figwidth(15)
    
    for ax, image in zip(axes, images):
        ax.imshow(io.imread(image), cmap)

# %%
#Visualise both the images & text present in the dataset
plot_image(all_imgs[0:5])

# %%
#Import the dataset and read the text file into a seperate variable
def load_doc(filename):
    
    file = open(filename)
    text = file.read()
    file.close()
   
    return text

doc = load_doc(CAPTIONS_FILE)
print(doc[:300])
# Out:
# image,caption
# 1000268201_693b08cb0e.jpg,A child in a pink dress is climbing up a set of stairs in an entry way .
# 1000268201_693b08cb0e.jpg,A girl going into a wooden building .
# 1000268201_693b08cb0e.jpg,A little girl climbing into a wooden playhouse .
# 1000268201_693b08cb0e.jpg,A little girl climbing

# %% [markdown]
# Create a dataframe which summarizes the image, path & captions as a dataframe
#
# Each image id has 5 captions associated with it therefore the total dataset should have 40455 samples.

# %%
def get_img_ids_and_captions(text):
    keys=[]
    values=[]
    key_paths=[]
    text=text.splitlines()[1:]
    for line in text:
        com_idx=line.index(",")
        im_id,im_cap=line[:com_idx],line[com_idx+1:]
        keys.append(im_id)
        values.append(im_cap)
        key_paths.append(IMAGE_PATH+'/'+im_id)
    return keys,key_paths, values

# %%
# all_img_id= #store all the image id here
# all_img_vector= #store all the image path here
# annotations= #store all the captions here

all_img_id, all_img_vector, annotations = get_img_ids_and_captions(doc)

df = pd.DataFrame(list(zip(all_img_id, all_img_vector,annotations)),columns =['ID','Path', 'Captions']) 
    
df.head()
# Out:
#                           ID  \
# 0  1000268201_693b08cb0e.jpg
# 1  1000268201_693b08cb0e.jpg
# 2  1000268201_693b08cb0e.jpg
# 3  1000268201_693b08cb0e.jpg
# 4  1000268201_693b08cb0e.jpg
#
#                                                 Path  \
# 0  ../input/flickr8k/Images//1000268201_693b08cb0...
# 1  ../input/flickr8k/Images//1000268201_693b08cb0...
# 2  ../input/flickr8k/Images//1000268201_693b08cb0...
# 3  ../input/flickr8k/Images//1000268201_693b08cb0...
# 4  ../input/flickr8k/Images//1000268201_693b08cb0...
#
#                                             Captions
# 0  A child in a pink dress is climbing up a set o...
# 1              A girl going into a wooden building .
# 2   A little girl climbing into a wooden playhouse .
# 3  A little girl climbing the stairs to her playh...
# 4  A little girl in a pink dress going into a woo...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40455 entries, 0 to 40454
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        40455 non-null  object
#  1   Path      40455 non-null  object
#  2   Captions  40455 non-null  object
# dtypes: object(3)
# memory usage: 948.3+ KB

# %%
def plot_image_captions(Pathlist,captionsList,fig,count=2,npix=299,nimg=2):
        image_load = load_img(Path,target_size=(npix,npix,3))
        ax = fig.add_subplot(nimg,2,count,xticks=[],yticks=[])
        ax.imshow(image_load)
        
        count +=1
        ax = fig.add_subplot(nimg,2,count)
        plt.axis('off')
        ax.plot()
        ax.set_xlim(0,1)
        ax.set_ylim(0,len(captions))
        for i, caption in enumerate(captions):
            ax.text(0,i,caption,fontsize=20)

# %%
# Images 
fig = plt.figure(figsize=(10,20))
count = 1
    
for Path in df[:20].Path.unique():
    captions = list(df["Captions"].loc[df.Path== Path].values)
    plot_image_captions(Path,captions,fig,count,299,5)
    count +=2
plt.show()

# %%
uni_filenames= np.unique(df.ID.values)
print("The number of unique file names : {}".format(len(uni_filenames)))
print("The distribution of the number of captions for each image:", Counter(Counter(df.ID.values).values()))
# Out:
# The number of unique file names : 8091
# The distribution of the number of captions for each image: Counter({5: 8091})

# %%
#Create the vocabulary & the counter for the captions
def voc_fetcher(frame,column):
    out=[]
    for i in frame[column]:
        out+=i.split(" ")
    return out

vocabulary=voc_fetcher(df,"Captions")
val_count=Counter(vocabulary)
val_count
# Out:
# Counter({'A': 21481,
#          'child': 1477,
#          'in': 18961,
#          'a': 40271,
#          'pink': 734,
#          'dress': 347,
#          'is': 9345,
#          'climbing': 502,
#          'up': 1260,
#          'set': 108,
#          'of': 6712,
#          'stairs': 109,
#          'an': 1944,
#          'entry': 1,
#          'way': 50,
#          '.': 34212,
#          'girl': 3217,
#          'going': 149,
#          'into': 1074,
#          'wooden': 284,
#          'building': 509,
#          'little': 1625,
#          'playhouse': 6,
#          'the': 15328,
#          'to': 3173,
#          'her': 1178,
#          'cabin': 4,
#          'black': 3696,
#          'dog': 7982,
#          'and': 8850,
#          'spotted': 37,
#          'are': 3503,
#          'fighting': 132,
#          'tri-colored': 14,
#          'playing': 2008,
#          'with': 7760,
#          'each': 430,
#          'other': 771,
#          'on': 10729,
#          'road': 388,
#          'white': 3875,
#          'brown': 2475,
#          'spots': 29,
#          'staring': 57,
#          'at': 2904,
#          'street': 936,
#          'Two': 3962,
#          'dogs': 2082,
#          'different': 45,
#          'breeds': 5,
#          'looking': 738,
#          'pavement': 48,
#          'moving': 41,
#          'toward': 146,
#          'covered': 306,
#          'paint': 61,
#          'sits': 577,
#          'front': 1386,
#          'painted': 63,
#          'rainbow': 22,
#          'hands': 244,
#          'bowl': 30,
#          'sitting': 1368,
#          'large': 1191,
#          'small': 1207,
#          'grass': 1621,
#          'plays': 526,
#          'fingerpaints': 3,
#          'canvas': 6,
#          'it': 398,
#          'There': 226,
#          'pigtails': 14,
#          'painting': 42,
#          'Young': 176,
#          'outside': 790,
#          'man': 6828,
#          'lays': 56,
#          'bench': 375,
#          'while': 1957,
#          'his': 2357,
#          'by': 1248,
#          'him': 402,
#          'which': 51,
#          'also': 20,
#          'tied': 15,
#          'sleeping': 60,
#          'next': 749,
#          'shirtless': 97,
#          'lies': 43,
#          'park': 503,
#          'laying': 188,
#          'holding': 1324,
#          'leash': 131,
#          'ground': 355,
#          'orange': 732,
#          'hat': 679,
#          'starring': 8,
#          'something': 346,
#          'wears': 115,
#          'glasses': 206,
#          'gauges': 2,
#          'wearing': 3061,
#          'Blitz': 1,
#          'beer': 45,
#          'can': 39,
#          'crocheted': 1,
#          'The': 2920,
#          'pierced': 6,
#          'ears': 69,
#          'rope': 249,
#          'net': 58,
#          'red': 2660,
#          'roping': 2,
#          'climbs': 200,
#          'bridge': 139,
#          'grips': 2,
#          'onto': 211,
#          'ropes': 38,
#          'playground': 201,
#          'running': 2072,
#          'grassy': 473,
#          'garden': 54,
#          'surrounded': 178,
#          'fence': 340,
#          'through': 2031,
#          'Boston': 9,
#          'terrier': 23,
#          'Terrier': 8,
#          'lush': 8,
#          'green': 1218,
#          'runs': 925,
#          'near': 1022,
#          '"A': 1186,
#          'shakes': 37,
#          'its': 925,
#          'head': 374,
#          'shore': 170,
#          ',': 3210,
#          'ball': 1778,
#          '."': 2365,
#          'edge': 170,
#          'beach': 1044,
#          '"Dog': 8,
#          'feet': 87,
#          'stands': 869,
#          'shaking': 71,
#          'off': 744,
#          'water"': 4,
#          'White': 60,
#          'water': 2774,
#          'standing': 1786,
#          'turned': 20,
#          'one': 1007,
#          'side': 303,
#          'boy': 3442,
#          'smiles': 192,
#          'stony': 3,
#          'wall': 555,
#          'city': 317,
#          'overalls': 24,
#          'working': 23,
#          'stone': 127,
#          'young': 2431,
#          'aross': 1,
#          'walking': 1165,
#          'paved': 43,
#          'metal': 113,
#          'pole': 155,
#          'behind': 631,
#          'Smiling': 13,
#          'shirt': 1803,
#          'blue': 2257,
#          'jeans': 224,
#          'rock': 750,
#          'leaps': 204,
#          'over': 1414,
#          'log': 55,
#          'grey': 239,
#          'leaping': 137,
#          'fallen': 70,
#          'tree': 416,
#          'mottled': 2,
#          'collar': 198,
#          'jumping': 1469,
#          'jumped': 33,
#          'stump': 27,
#          'snow': 1481,
#          'field': 1276,
#          'surface': 65,
#          'displaying': 5,
#          'pictures': 66,
#          'skier': 173,
#          'skis': 81,
#          'past': 148,
#          'another': 953,
#          'paintings': 5,
#          'person': 1414,
#          'framed': 7,
#          'looks': 511,
#          'trees': 260,
#          'Man': 410,
#          'artwork': 4,
#          'for': 949,
#          'sale': 7,
#          'collage': 2,
#          'cliff': 195,
#          'group': 1172,
#          'people': 2442,
#          'belays': 1,
#          'Seven': 12,
#          'climbers': 27,
#          'ascending': 8,
#          'face': 482,
#          'whilst': 152,
#          'Several': 188,
#          'row': 33,
#          'watches': 275,
#          'holds': 471,
#          'line': 147,
#          'chases': 99,
#          'from': 920,
#          'sprinkler': 53,
#          'lawn': 117,
#          'hose': 45,
#          'Large': 42,
#          'away': 169,
#          'prepares': 50,
#          'catch': 368,
#          'thrown': 45,
#          'object': 155,
#          'nearby': 153,
#          'cars': 63,
#          'about': 151,
#          'yellow': 1207,
#          'mouth': 986,
#          'toy': 580,
#          'ready': 125,
#          'flying': 173,
#          'air': 1057,
#          'after': 184,
#          'get': 107,
#          'jumps': 978,
#          'towards': 247,
#          'trying': 163,
#          'midair': 210,
#          'woman': 3227,
#          'waters': 29,
#          'big': 272,
#          'lake': 332,
#          'lone': 80,
#          'duck': 36,
#          'swimming': 446,
#          'several': 113,
#          'around': 647,
#          'watching': 250,
#          'waves': 141,
#          'hand': 342,
#          '"Two': 403,
#          'facing': 55,
#          'skyline': 15,
#          'couple': 239,
#          'infant': 14,
#          'being': 338,
#          'held': 66,
#          'male': 111,
#          'pond': 96,
#          'stroller': 28,
#          'sit': 360,
#          'baby': 403,
#          'their': 693,
#          'newborn': 8,
#          'under': 246,
#          'care': 3,
#          'along': 527,
#          'body': 190,
#          'Couple': 8,
#          'outdoors': 174,
#          'surf': 78,
#          'lab': 22,
#          'tags': 7,
#          'frolicks': 2,
#          'splashes': 71,
#          'This': 96,
#          'splashing': 129,
#          'drilling': 5,
#          'hole': 37,
#          'ice': 220,
#          'frozen': 26,
#          'men': 1035,
#          'fishing': 106,
#          'play': 746,
#          'making': 154,
#          'turn': 70,
#          'soft': 13,
#          'sand': 465,
#          'together': 413,
#          'tan': 385,
#          'sandy': 110,
#          'uses': 27,
#          'picks': 12,
#          'crampons': 1,
#          'scale': 1,
#          'climber': 121,
#          'jacket': 678,
#          'pants': 259,
#          'scaling': 20,
#          'An': 455,
#          'waterfall': 85,
#          'two': 1262,
#          'Climber': 3,
#          'carries': 128,
#          'as': 865,
#          'he': 205,
#          'walks': 552,
#          'carrying': 434,
#          'has': 562,
#          'item': 20,
#          'wet': 169,
#          'kayak': 88,
#          'life': 86,
#          'jackets': 68,
#          'rowing': 35,
#          'canoe': 72,
#          'gentle': 1,
#          'ride': 253,
#          'courtyard': 28,
#          'catching': 109,
#          'Black': 129,
#          'snaps': 1,
#          'lunges': 6,
#          'Chocolate': 2,
#          'Lab': 2,
#          'too': 8,
#          'late': 3,
#          'captures': 1,
#          'driveway': 15,
#          'stick': 467,
#          'kneeling': 34,
#          'goalie': 43,
#          'hockey': 182,
#          'guarding': 9,
#          'goal': 82,
#          'kid': 171,
#          'rink': 30,
#          'right': 93,
#          '"Hockey': 1,
#          'crouches': 30,
#          'modern': 5,
#          'art': 39,
#          'structure': 77,
#          'glass': 61,
#          'reads': 46,
#          'newspaper': 38,
#          'sculpture': 22,
#          'office': 12,
#          'statue': 63,
#          'backpack': 158,
#          'buildings': 71,
#          'reading': 96,
#          'tent': 82,
#          'enter': 8,
#          'setting': 81,
#          'hut': 12,
#          'iced': 3,
#          'tarp': 8,
#          'snowy': 420,
#          'three': 298,
#          'Three': 968,
#          'hill': 444,
#          'sky': 146,
#          'them': 260,
#          'stand': 518,
#          'kneels': 26,
#          'skyscraper': 6,
#          'very': 162,
#          'tall': 144,
#          'Behind': 1,
#          'distance': 108,
#          'camera': 687,
#          'bites': 31,
#          'hard': 16,
#          'treat': 16,
#          'biting': 83,
#          'baked': 2,
#          'good': 7,
#          'putting': 35,
#          'both': 81,
#          'eats': 52,
#          'food': 92,
#          'table': 258,
#          'eating': 144,
#          'pizza': 4,
#          'tin': 1,
#          'dish': 11,
#          'People': 414,
#          'mountainside': 26,
#          'check': 6,
#          'out': 757,
#          'view': 80,
#          'hilltop': 2,
#          'overlooking': 104,
#          'valley': 23,
#          'hang': 30,
#          'top': 485,
#          'overlook': 6,
#          'rest': 24,
#          'ledge': 77,
#          'above': 226,
#          'moutains': 1,
#          'down': 1823,
#          'many': 89,
#          'inflatable': 73,
#          'boats': 39,
#          'kayakers': 8,
#          'railing': 112,
#          'rafts': 6,
#          'below': 55,
#          'crowd': 519,
#          'jersey': 114,
#          'pose': 216,
#          'some': 547,
#          'multiracial': 1,
#          'posing': 291,
#          'picture': 416,
#          '"Asian': 4,
#          'blond': 169,
#          'background': 592,
#          'Guy': 15,
#          'striped': 217,
#          'guy': 195,
#          'takeout': 1,
#          'television': 9,
#          'floor': 153,
#          'fast': 51,
#          'meal': 13,
#          'Someone': 86,
#          'TV': 8,
#          'teens': 5,
#          'Crowd': 11,
#          'rail': 102,
#          'crowded': 76,
#          'takes': 169,
#          'jump': 401,
#          'skateboard': 431,
#          'performing': 196,
#          'trick': 384,
#          'leans': 57,
#          'skateboarder': 290,
#          'doing': 434,
#          'board': 139,
#          'platform': 48,
#          'skateboarders': 9,
#          'paddling': 48,
#          'river': 235,
#          'seen': 40,
#          'kayaking': 29,
#          'paddles': 34,
#          'boat': 274,
#          'paddle': 40,
#          'shallow': 130,
#          'girls': 807,
#          'ocean': 460,
#          'four': 132,
#          'children': 1005,
#          'pajamas': 18,
#          'have': 74,
#          'pillow': 15,
#          'fight': 77,
#          'kids': 292,
#          'pillow-fight': 1,
#          'bed': 156,
#          'Children': 143,
#          'having': 48,
#          'Four': 332,
#          'constructions': 1,
#          'workers': 17,
#          'beam': 20,
#          'taking': 204,
#          'break': 33,
#          'construction': 31,
#          'I-beam': 1,
#          'take': 80,
#          'seat': 50,
#          'steel': 4,
#          'boys': 634,
#          'puddle': 93,
#          'balloon': 44,
#          'mud': 114,
#          'sunny': 66,
#          'day': 136,
#          'appears': 36,
#          'wait': 43,
#          'hailing': 1,
#          'taxi': 4,
#          'signaling': 1,
#          'traffic': 47,
#          'blonde': 186,
#          'hair': 413,
#          'tube': 61,
#          'waving': 52,
#          'arm': 148,
#          'oncoming': 2,
#          'brochure': 2,
#          'train': 108,
#          'rides': 458,
#          'magizine': 1,
#          'book': 77,
#          'pamphlet': 1,
#          'Child': 58,
#          'rocky': 244,
#          'run': 366,
#          'across': 476,
#          'stones': 9,
#          'area': 398,
#          'descends': 11,
#          'end': 52,
#          'high': 282,
#          'diving': 73,
#          'pool': 690,
#          'dive': 11,
#          'window': 136,
#          'overshirt': 1,
#          'tank': 76,
#          'chrome': 1,
#          'door': 61,
#          'puts': 34,
#          'elevator': 7,
#          'light-colored': 5,
#          'Light': 5,
#          'swim': 97,
#          'shorts': 376,
#          'trunks': 95,
#          'arms': 247,
#          'outstretched': 38,
#          'hiker': 75,
#          'bluff': 5,
#          'mountains': 204,
#          'ski': 95,
#          "'s": 400,
#          'landscape': 45,
#          'snow-covered': 49,
#          'mountain': 543,
#          'beautiful': 48,
#          'pauses': 10,
#          'mountaintop': 25,
#          'attempting': 57,
#          'purple': 312,
#          'low': 66,
#          'cut': 27,
#          'yard': 201,
#          'Frisbee': 337,
#          'parking': 72,
#          'lot': 108,
#          'middle': 153,
#          'during': 169,
#          'heavy': 25,
#          'mat': 22,
#          'between': 125,
#          'SUV': 14,
#          'pickup': 4,
#          'open': 190,
#          'busy': 97,
#          'terrain': 34,
#          'woolly': 1,
#          'Doberman': 6,
#          'One': 193,
#          'chasing': 184,
#          'catches': 123,
#          'tennis': 424,
#          ',"': 22,
#          'multicolor': 11,
#          'balloons': 28,
#          'night': 158,
#          'hot': 27,
#          'lit': 43,
#          'lined': 36,
#          'nighttime': 12,
#          'helmet': 358,
#          'bike': 859,
#          'miniature': 5,
#          'dirt': 581,
#          'bicycle': 414,
#          'race': 372,
#          'pedals': 3,
#          'quickly': 30,
#          'BMX': 37,
#          'eight': 9,
#          'gathered': 68,
#          'dark': 242,
#          'porch': 24,
#          'darkened': 10,
#          'room': 132,
#          'throwing': 109,
#          'cleans': 2,
#          'bubbles': 89,
#          'suds': 4,
#          'wiped': 2,
#          'clean': 7,
#          'foam': 20,
#          'ramp': 319,
#          'soapy': 1,
#          'getting': 124,
#          'cleaned': 1,
#          'slides': 92,
#          'slide': 300,
#          'wading': 55,
#          'toys': 49,
#          'floating': 38,
#          'backyard': 66,
#          'sliding': 123,
#          'colorful': 217,
#          'tubes': 2,
#          'falling': 80,
#          'colored': 170,
#          'wetsuit': 81,
#          'toddler': 164,
#          'waiting': 118,
#          'come': 11,
#          'so': 16,
#          '"While': 11,
#          'droplets': 7,
#          'fly': 37,
#          'throws': 67,
#          'sticks': 62,
#          'tongue': 111,
#          'Another': 2,
#          'make': 58,
#          'faces': 74,
#          'smiling': 448,
#          'sticking': 53,
#          'look': 257,
#          'silly': 17,
#          'horse': 229,
#          'sweatshirt': 78,
#          'fire': 109,
#          'barrel': 22,
#          'lead': 17,
#          'horses': 89,
#          'contained': 1,
#          'bulldog': 9,
#          'sheep': 55,
#          'boxer': 18,
#          'pushing': 64,
#          'anouther': 1,
#          'skinny': 18,
#          'smaller': 67,
#          'int': 6,
#          'various': 15,
#          'sizes': 4,
#          'lady': 207,
#          'no': 84,
#          'dock': 93,
#          'deck': 39,
#          'closeup': 50,
#          'that': 396,
#          'paws': 30,
#          'lying': 99,
#          'resting': 44,
#          'tiled': 9,
#          'eyes': 92,
#          'rests': 23,
#          'patio': 21,
#          'bricks': 5,
#          'artificial': 10,
#          'safety': 32,
#          'harness': 82,
#          'indoor': 43,
#          '"The': 169,
#          'rocks': 255,
#          'Woman': 158,
#          'ring': 68,
#          'jumphouse': 1,
#          'teenage': 71,
#          'seating': 7,
#          'inflated': 5,
#          'family': 79,
#          'tractor': 9,
#          'Polaris': 3,
#          'vehicle': 79,
#          'played': 19,
#          'wheeler': 12,
#          'riding': 906,
#          'ATV': 39,
#          'costume': 131,
#          'left': 89,
#          'sequined': 4,
#          'feather': 12,
#          'sidewalk': 375,
#          'salmon': 2,
#          'bikini': 66,
#          ';': 32,
#          'outfit': 159,
#          'drinking': 100,
#          'pop': 7,
#          'approached': 2,
#          'flamboyant': 3,
#          'dressed': 563,
#          'feathered': 8,
#          'headress': 1,
#          'Skiiers': 9,
#          'forest': 160,
#          'skiing': 112,
#          'wooded': 101,
#          'cross-country': 18,
#          'skiers': 31,
#          'woodland': 21,
#          'trail': 146,
#          'woods': 210,
#          'hikers': 33,
#          'pathway': 12,
#          'light': 157,
#          'path': 324,
#          'happily': 26,
#          'Energetic': 1,
#          'mother': 40,
#          'boardwalk': 24,
#          'sea': 30,
#          'Some': 76,
#          'pier': 33,
#          'evening': 9,
#          'pony': 12,
#          'wintertime': 2,
#          'atop': 37,
#          'draft': 3,
#          'n': 2,
#          'daft': 1,
#          'pull': 32,
#          'cart': 85,
#          'golden': 101,
#          'sleigh': 4,
#          'driven': 10,
#          'coat': 268,
#          'pulling': 110,
#          'carriage': 19,
#          'sled': 113,
#          'steered': 2,
#          'sheer': 16,
#          'using': 64,
#          'flat': 14,
#          'rappels': 2,
#          'steep': 62,
#          'incline': 11,
#          'vest': 98,
#          'inside': 172,
#          'dome': 3,
#          'Shaft': 1,
#          'cave': 21,
#          'shows': 32,
#          'spelunkers': 1,
#          'Spelunkers': 1,
#          'cavern': 1,
#          'bathed': 1,
#          'sunlight': 11,
#          'backpackers': 2,
#          'lay': 20,
#          'dry': 79,
#          'camp': 6,
#          'gear': 115,
#          'chalk': 17,
#          'portrait': 6,
#          'stream': 111,
#          'drawing': 13,
#          'barn-like': 1,
#          'elaborate': 11,
#          'illustration': 2,
#          'deep': 82,
#          'pile': 76,
#          'fountain': 181,
#          'fountains': 14,
#          'sprayed': 25,
#          'Corgi': 2,
#          'tunnel': 67,
#          'course': 135,
#          'Dog': 144,
#          'obstacle': 125,
#          'obedience': 3,
#          'swimsuit': 61,
#          'Little': 129,
#          'handrail': 33,
#          'bathing': 119,
#          'suit': 244,
#          'spray': 36,
#          'soaked': 12,
#          'jet': 22,
#          'shower': 20,
#          'gets': 107,
#          'underwater': 53,
#          'red-headed': 4,
#          'swims': 104,
#          'gun': 41,
#          'foot': 44,
#          'aims': 5,
#          'fireplace': 11,
#          'new': 7,
#          'light-up': 2,
#          'Boy': 119,
#          'pointed': 13,
#          'alone': 35,
#          'jagged': 7,
#          'snowmobile': 13,
#          'mid': 8,
#          'snowmobiler': 1,
#          'flies': 104,
#          'rider': 183,
#          'or': 87,
#          'machine': 31,
#          'pine': 23,
#          'Rider': 2,
#          'rural': 45,
#          'snowmobiles': 4,
#          'helmets': 39,
#          'goggles': 73,
#          'snowmobiling': 2,
#          'helmeted': 14,
#          'drive': 16,
#          'ATVs': 3,
#          'heads': 49,
#          'wheel': 60,
#          'wheelers': 3,
#          'empty': 49,
#          'all': 137,
#          '!': 9,
#          'gin': 1,
#          'four-wheeler': 5,
#          'airborne': 73,
#          'quad': 6,
#          'harvested': 2,
#          'cornfield': 1,
#          's': 2,
#          'happy': 20,
#          'OD': 1,
#          'playfully': 32,
#          'soccer': 570,
#          'tucked': 1,
#          't-shirt': 145,
#          'Small': 64,
#          'artist': 14,
#          'paints': 12,
#          'clouds': 32,
#          'braids': 6,
#          'colors': 22,
#          'paper': 79,
#          'cyclist': 65,
#          'curved': 4,
#          'aerodynamic': 2,
#          'sharp': 20,
#          'curve': 24,
#          'pedaling': 3,
#          '"Man': 26,
#          'cows': 12,
#          'graze': 2,
#          'biker': 162,
#          'fetch': 31,
#          'pounces': 8,
#          'cine': 1,
#          'old': 161,
#          'fashioned': 6,
#          'video': 39,
#          'steadies': 2,
#          'aim': 4,
#          'Girl': 103,
#          'rosy': 1,
#          'cheeks': 6,
#          'lips': 17,
#          'Border': 2,
#          'Collie': 7,
#          'audience': 38,
#          'dug': 3,
#          'watch': 239,
#          'agile': 1,
#          'onlookers': 48,
#          'closely': 5,
#          'smooth': 6,
#          'stacking': 1,
#          'Toddler': 3,
#          'against': 201,
#          'backdrop': 9,
#          'shoes': 91,
#          'rappeling': 1,
#          'headlamp': 2,
#          'attached': 53,
#          'snakeskin': 1,
#          'Person': 122,
#          'sprays': 11,
#          'frog': 2,
#          'public': 48,
#          'wood': 72,
#          'barrior': 1,
#          'animal': 96,
#          'bird': 191,
#          'seeds': 6,
#          'someone': 72,
#          'sunflower': 1,
#          'clinging': 5,
#          'finger': 36,
#          'wades': 12,
#          'guided': 3,
#          'laughs': 33,
#          'playful': 7,
#          'this': 23,
#          'beige': 54,
#          'torwards': 1,
#          'outdoor': 136,
#          'handstand': 48,
#          'does': 232,
#          'sheets': 5,
#          'upside': 96,
#          'snowboard': 88,
#          'surfboard': 146,
#          'bikes': 86,
#          'traveling': 16,
#          'worn': 5,
#          'motorcycles': 27,
#          'motorbikes': 7,
#          'follow': 14,
#          'dirt-bikes': 1,
#          'off-road': 10,
#          'garment': 2,
#          'flag': 98,
#          'crescent': 1,
#          'moon': 5,
#          'star': 9,
#          'gown': 9,
#          'Muslim': 3,
#          'helps': 28,
#          'wave': 317,
#          'Baby': 14,
#          'half': 31,
#          'naked': 46,
#          'chair': 132,
#          'older': 205,
#          'back': 378,
#          'relaxes': 12,
#          'adobe': 1,
#          'where': 34,
#          'bicycles': 54,
#          'propped': 4,
#          'cap': 195,
#          'close': 43,
#          'parked': 41,
#          'relaxing': 15,
#          'folding': 11,
#          '"Topless': 2,
#          'slippers': 2,
#          'navy': 14,
#          'reclining': 2,
#          'hauling': 1,
#          'Both': 2,
#          'retrieve': 9,
#          'mouths': 40,
#          'tug': 30,
#          'chew': 16,
#          '"There': 43,
#          'haired': 145,
#          'bottled': 2,
#          'drink': 106,
#          'tilted': 4,
#          'spiked': 4,
#          'party': 56,
#          'streets': 28,
#          'they': 116,
#          'women': 612,
#          'parade': 68,
#          'neck-deep': 1,
#          'vegetation': 4,
#          'filled': 44,
#          '"Brown': 14,
#          'bushes': 37,
#          'creating': 8,
#          'splash': 44,
#          'seaweed': 11,
#          'lav': 1,
#          'swimmers': 10,
#          'kelp': 1,
#          'foreground': 40,
#          'sandals': 21,
#          'short': 69,
#          'sleeved': 14,
#          'pinstripe': 2,
#          'snows': 4,
#          'furry': 59,
#          'attempts': 56,
#          'itself': 20,
#          'self': 5,
#          'backpacks': 32,
#          'placed': 9,
#          'cardboard': 27,
#          'bus': 81,
#          'station': 34,
#          'bouncing': 29,
#          'folded': 9,
#          'beds': 3,
#          'bedroom': 5,
#          'snowboarder': 220,
#          'slope': 76,
#          'boarders': 1,
#          'Snowboarders': 3,
#          'slopes': 7,
#          'clothing': 130,
#          'store': 111,
#          ...})

# %%
#Visualise the top 30 occuring words in the captions
most_occur = val_count.most_common(30)
print(most_occur)
# Out:
# [('a', 40271), ('.', 34212), ('A', 21481), ('in', 18961), ('the', 15328), ('on', 10729), ('is', 9345), ('and', 8850), ('dog', 7982), ('with', 7760), ('man', 6828), ('of', 6712), ('Two', 3962), ('white', 3875), ('black', 3696), ('are', 3503), ('boy', 3442), ('woman', 3227), ('girl', 3217), (',', 3210), ('to', 3173), ('wearing', 3061), ('The', 2920), ('at', 2904), ('water', 2774), ('red', 2660), ('brown', 2475), ('people', 2442), ('young', 2431), ('."', 2365)]

# %%
df_word = pd.DataFrame.from_dict(val_count, orient = 'index')
df_word = df_word.sort_values(by = [0], ascending=False).reset_index()
df_word = df_word.rename(columns={'index':'word', 0:'count'})

df_word.head()
# Out:
#   word  count
# 0    a  40271
# 1    .  34212
# 2    A  21481
# 3   in  18961
# 4  the  15328

# %%
#Visualise the top 30 occuring words in the captions
def plthist(index,words,count, title="The top 30 most frequently appearing words"):
    plt.figure(figsize=(20,4))
    plt.bar(words,count,color='maroon', width =0.4)
    plt.xlabel("Words",  fontsize=20) 
    plt.ylabel("Word Count",rotation=90,fontsize=20) 
   # plt.yticks(fontsize=20)
    plt.xticks(index,words,rotation=90,fontsize=20)
    plt.title(title,fontsize=20)
    plt.show()
    
words = list(df_word[:30].word)

count =list(df_word['count'][:30])
plthist(list(range(0,30)),words,count)

# %%
#Create a list which contains all the captions
annotations = df.Captions.apply(lambda z:"<start>"+" "+z+" "+"<end>") #add the <start> & <end> token to all those captions as well

#Create a list which contains all the path to the images
all_img_path = df.Path.to_list()

print("Total captions present in the dataset: "+ str(len(annotations)))
print("Total images present in the dataset: " + str(len(all_img_path)))
# Out:
# Total captions present in the dataset: 40455
# Total images present in the dataset: 40455

# %% [markdown]
# ## Pre-Processing the captions
# 1.Create the tokenized vectors by tokenizing the captions fore ex :split them using spaces & other filters.
# This gives us a vocabulary of all of the unique words in the data. Keep the total vocaublary to top 5,000 words for saving memory.
#
# 2.Replace all other words with the unknown token "UNK" .
#
# 3.Create word-to-index and index-to-word mappings.
#
# 4.Pad all sequences to be the same length as the longest one.

# %%
# create the tokenizer
top_word_cnt = 5000
special_chars = '!"#$%&()*+.,-/:;=?@[\]^_`{|}~ '
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=top_word_cnt,
                                                  oov_token="<unk>",
                                                  filters=special_chars)
tokenizer.fit_on_texts(annotations)
train_seqs = tokenizer.texts_to_sequences(annotations)

# %%
train_seqs[:5]
# Out:
# [[3, 2, 44, 5, 2, 91, 173, 8, 120, 52, 2, 394, 13, 395, 5, 29, 1, 671, 4],
#  [3, 2, 20, 317, 65, 2, 197, 118, 4],
#  [3, 2, 41, 20, 120, 65, 2, 197, 2438, 4],
#  [3, 2, 41, 20, 120, 6, 395, 21, 61, 2438, 4],
#  [3, 2, 41, 20, 5, 2, 91, 173, 317, 65, 2, 197, 2982, 4]]

# %%
annotations[:5]
# Out:
# 0    <start> A child in a pink dress is climbing up...
# 1    <start> A girl going into a wooden building . ...
# 2    <start> A little girl climbing into a wooden p...
# 3    <start> A little girl climbing the stairs to h...
# 4    <start> A little girl in a pink dress going in...
# Name: Captions, dtype: object

# %%
# Create word-to-index and index-to-word mappings.
tokenizer.word_index['<pad>'] = 0
tokenizer.index_word[0] = '<pad>'
train_seqs = tokenizer.texts_to_sequences(annotations)

# %%
tokenizer.word_counts
# Out:
# OrderedDict([('<start>', 40455),
#              ('a', 62992),
#              ('child', 1545),
#              ('in', 18986),
#              ('pink', 739),
#              ('dress', 348),
#              ('is', 9345),
#              ('climbing', 507),
#              ('up', 1302),
#              ('set', 109),
#              ('of', 6723),
#              ('stairs', 109),
#              ('an', 2432),
#              ('entry', 1),
#              ('way', 53),
#              ('<end>', 40455),
#              ('girl', 3328),
#              ('going', 149),
#              ('into', 1074),
#              ('wooden', 284),
#              ('building', 510),
#              ('little', 1768),
#              ('playhouse', 6),
#              ('the', 18419),
#              ('to', 3176),
#              ('her', 1178),
#              ('cabin', 4),
#              ('black', 3848),
#              ('dog', 8138),
#              ('and', 8862),
#              ('spotted', 38),
#              ('are', 3504),
#              ('fighting', 133),
#              ('tri', 14),
#              ('colored', 221),
#              ('playing', 2008),
#              ('with', 7765),
#              ('each', 430),
#              ('other', 773),
#              ('on', 10745),
#              ('road', 398),
#              ('white', 3959),
#              ('brown', 2578),
#              ('spots', 29),
#              ('staring', 57),
#              ('at', 2915),
#              ('street', 944),
#              ('two', 5642),
#              ('dogs', 2125),
#              ('different', 46),
#              ('breeds', 5),
#              ('looking', 743),
#              ('pavement', 48),
#              ('moving', 41),
#              ('toward', 146),
#              ('covered', 372),
#              ('paint', 62),
#              ('sits', 577),
#              ('front', 1386),
#              ('painted', 64),
#              ('rainbow', 22),
#              ('hands', 246),
#              ('bowl', 30),
#              ('sitting', 1368),
#              ('large', 1236),
#              ('small', 1278),
#              ('grass', 1622),
#              ('plays', 526),
#              ('fingerpaints', 3),
#              ('canvas', 6),
#              ('it', 401),
#              ('there', 304),
#              ('pigtails', 14),
#              ('painting', 43),
#              ('young', 2630),
#              ('outside', 791),
#              ('man', 7274),
#              ('lays', 56),
#              ('bench', 375),
#              ('while', 1968),
#              ('his', 2357),
#              ('by', 1249),
#              ('him', 403),
#              ('which', 51),
#              ('also', 20),
#              ('tied', 15),
#              ('sleeping', 60),
#              ('next', 749),
#              ('shirtless', 104),
#              ('lies', 43),
#              ('park', 508),
#              ('laying', 189),
#              ('holding', 1324),
#              ('leash', 131),
#              ('ground', 357),
#              ('orange', 745),
#              ('hat', 682),
#              ('starring', 8),
#              ('something', 346),
#              ('wears', 115),
#              ('glasses', 206),
#              ('gauges', 2),
#              ('wearing', 3062),
#              ('blitz', 1),
#              ('beer', 45),
#              ('can', 39),
#              ('crocheted', 1),
#              ('pierced', 6),
#              ('ears', 69),
#              ('rope', 251),
#              ('net', 58),
#              ('red', 2691),
#              ('roping', 2),
#              ('climbs', 201),
#              ('bridge', 141),
#              ('grips', 2),
#              ('onto', 211),
#              ('ropes', 38),
#              ('playground', 201),
#              ('running', 2073),
#              ('grassy', 474),
#              ('garden', 54),
#              ('surrounded', 178),
#              ('fence', 340),
#              ('through', 2032),
#              ('boston', 9),
#              ('terrier', 31),
#              ('lush', 8),
#              ('green', 1234),
#              ('runs', 925),
#              ('near', 1025),
#              ('shakes', 37),
#              ('its', 925),
#              ('head', 377),
#              ('shore', 170),
#              ('ball', 1783),
#              ('edge', 170),
#              ('beach', 1046),
#              ('feet', 87),
#              ('stands', 869),
#              ('shaking', 71),
#              ('off', 766),
#              ('water', 2790),
#              ('standing', 1787),
#              ('turned', 20),
#              ('one', 1222),
#              ('side', 306),
#              ('boy', 3581),
#              ('smiles', 192),
#              ('stony', 3),
#              ('wall', 557),
#              ('city', 319),
#              ('overalls', 24),
#              ('working', 24),
#              ('stone', 128),
#              ('aross', 1),
#              ('walking', 1165),
#              ('paved', 43),
#              ('metal', 115),
#              ('pole', 157),
#              ('behind', 633),
#              ('smiling', 464),
#              ('shirt', 1962),
#              ('blue', 2279),
#              ('jeans', 225),
#              ('rock', 759),
#              ('leaps', 204),
#              ('over', 1415),
#              ('log', 55),
#              ('grey', 249),
#              ('leaping', 138),
#              ('fallen', 70),
#              ('tree', 427),
#              ('mottled', 2),
#              ('collar', 198),
#              ('jumping', 1473),
#              ('jumped', 33),
#              ('stump', 28),
#              ('snow', 1547),
#              ('field', 1283),
#              ('surface', 65),
#              ('displaying', 5),
#              ('pictures', 67),
#              ('skier', 179),
#              ('skis', 82),
#              ('past', 148),
#              ('another', 956),
#              ('paintings', 5),
#              ('person', 1542),
#              ('framed', 7),
#              ('looks', 512),
#              ('trees', 261),
#              ('artwork', 4),
#              ('for', 949),
#              ('sale', 7),
#              ('collage', 2),
#              ('cliff', 195),
#              ('group', 1218),
#              ('people', 2883),
#              ('belays', 1),
#              ('seven', 31),
#              ('climbers', 27),
#              ('ascending', 8),
#              ('face', 486),
#              ('whilst', 152),
#              ('several', 314),
#              ('row', 34),
#              ('watches', 276),
#              ('holds', 471),
#              ('line', 152),
#              ('chases', 99),
#              ('from', 920),
#              ('sprinkler', 53),
#              ('lawn', 117),
#              ('hose', 45),
#              ('away', 170),
#              ('prepares', 50),
#              ('catch', 368),
#              ('thrown', 45),
#              ('object', 155),
#              ('nearby', 153),
#              ('cars', 65),
#              ('about', 152),
#              ('yellow', 1217),
#              ('mouth', 989),
#              ('toy', 582),
#              ('ready', 125),
#              ('flying', 174),
#              ('air', 1062),
#              ('after', 184),
#              ('get', 107),
#              ('jumps', 979),
#              ('towards', 247),
#              ('trying', 163),
#              ('midair', 210),
#              ('woman', 3402),
#              ('waters', 29),
#              ('big', 280),
#              ('lake', 332),
#              ('lone', 82),
#              ('duck', 37),
#              ('swimming', 446),
#              ('around', 648),
#              ('watching', 251),
#              ('waves', 142),
#              ('hand', 349),
#              ('facing', 55),
#              ('skyline', 15),
#              ('couple', 248),
#              ('infant', 15),
#              ('being', 338),
#              ('held', 66),
#              ('male', 114),
#              ('pond', 96),
#              ('stroller', 28),
#              ('sit', 360),
#              ('baby', 419),
#              ('their', 693),
#              ('newborn', 8),
#              ('under', 246),
#              ('care', 3),
#              ('along', 527),
#              ('body', 192),
#              ('outdoors', 175),
#              ('surf', 78),
#              ('lab', 24),
#              ('tags', 7),
#              ('frolicks', 2),
#              ('splashes', 71),
#              ('this', 142),
#              ('splashing', 129),
#              ('drilling', 5),
#              ('hole', 37),
#              ('ice', 222),
#              ('frozen', 26),
#              ('men', 1121),
#              ('fishing', 107),
#              ('play', 747),
#              ('making', 154),
#              ('turn', 70),
#              ('soft', 13),
#              ('sand', 467),
#              ('together', 413),
#              ('tan', 394),
#              ('sandy', 111),
#              ('uses', 27),
#              ('picks', 12),
#              ('crampons', 1),
#              ('scale', 1),
#              ('climber', 125),
#              ('jacket', 678),
#              ('pants', 259),
#              ('scaling', 20),
#              ('waterfall', 85),
#              ('carries', 128),
#              ('as', 868),
#              ('he', 209),
#              ('walks', 552),
#              ('carrying', 434),
#              ('has', 562),
#              ('item', 20),
#              ('wet', 182),
#              ('kayak', 89),
#              ('life', 87),
#              ('jackets', 68),
#              ('rowing', 35),
#              ('canoe', 72),
#              ('gentle', 1),
#              ('ride', 255),
#              ('courtyard', 28),
#              ('catching', 109),
#              ('snaps', 1),
#              ('lunges', 6),
#              ('chocolate', 15),
#              ('too', 8),
#              ('late', 3),
#              ('captures', 1),
#              ('driveway', 15),
#              ('stick', 467),
#              ('kneeling', 34),
#              ('goalie', 43),
#              ('hockey', 195),
#              ('guarding', 9),
#              ('goal', 85),
#              ('kid', 183),
#              ('rink', 30),
#              ('right', 95),
#              ('crouches', 30),
#              ('modern', 5),
#              ('art', 40),
#              ('structure', 77),
#              ('glass', 61),
#              ('reads', 46),
#              ('newspaper', 38),
#              ('sculpture', 22),
#              ('office', 12),
#              ('statue', 63),
#              ('backpack', 159),
#              ('buildings', 71),
#              ('reading', 96),
#              ('tent', 84),
#              ('enter', 8),
#              ('setting', 82),
#              ('hut', 12),
#              ('iced', 3),
#              ('tarp', 8),
#              ('snowy', 422),
#              ('three', 1387),
#              ('hill', 445),
#              ('sky', 147),
#              ('them', 260),
#              ('stand', 519),
#              ('kneels', 26),
#              ('skyscraper', 6),
#              ('very', 163),
#              ('tall', 146),
#              ('distance', 109),
#              ('camera', 700),
#              ('bites', 31),
#              ('hard', 19),
#              ('treat', 16),
#              ('biting', 83),
#              ('baked', 2),
#              ('good', 7),
#              ('putting', 35),
#              ('both', 83),
#              ('eats', 52),
#              ('food', 93),
#              ('table', 258),
#              ('eating', 144),
#              ('pizza', 10),
#              ('tin', 1),
#              ('dish', 11),
#              ('mountainside', 26),
#              ('check', 7),
#              ('out', 763),
#              ('view', 85),
#              ('hilltop', 2),
#              ('overlooking', 104),
#              ('valley', 23),
#              ('hang', 33),
#              ('top', 488),
#              ('overlook', 6),
#              ('rest', 24),
#              ('ledge', 77),
#              ('above', 228),
#              ('moutains', 1),
#              ('down', 1843),
#              ('many', 185),
#              ('inflatable', 73),
#              ('boats', 41),
#              ('kayakers', 8),
#              ('railing', 113),
#              ('rafts', 6),
#              ('below', 55),
#              ('crowd', 531),
#              ('jersey', 114),
#              ('pose', 216),
#              ('some', 626),
#              ('multiracial', 1),
#              ('posing', 291),
#              ('picture', 419),
#              ('asian', 202),
#              ('blond', 194),
#              ('background', 595),
#              ('guy', 210),
#              ('striped', 220),
#              ('takeout', 1),
#              ('television', 9),
#              ('floor', 154),
#              ('fast', 53),
#              ('meal', 14),
#              ('someone', 161),
#              ('tv', 13),
#              ('teens', 7),
#              ('rail', 103),
#              ('crowded', 78),
#              ('takes', 170),
#              ('jump', 406),
#              ('skateboard', 435),
#              ('performing', 196),
#              ('trick', 385),
#              ('leans', 57),
#              ('skateboarder', 315),
#              ('doing', 434),
#              ('board', 143),
#              ('platform', 48),
#              ('skateboarders', 11),
#              ('paddling', 48),
#              ('river', 237),
#              ('seen', 40),
#              ('kayaking', 29),
#              ('paddles', 34),
#              ('boat', 276),
#              ('paddle', 40),
#              ('shallow', 130),
#              ('girls', 844),
#              ('ocean', 463),
#              ('four', 501),
#              ('children', 1156),
#              ('pajamas', 18),
#              ('have', 74),
#              ('pillow', 16),
#              ('fight', 78),
#              ('kids', 340),
#              ('bed', 157),
#              ('having', 48),
#              ('constructions', 1),
#              ('workers', 18),
#              ('beam', 21),
#              ('taking', 205),
#              ('break', 33),
#              ('construction', 31),
#              ('i', 17),
#              ('take', 81),
#              ('seat', 50),
#              ('steel', 4),
#              ('boys', 666),
#              ('puddle', 93),
#              ('balloon', 44),
#              ('mud', 115),
#              ('sunny', 66),
#              ('day', 139),
#              ('appears', 36),
#              ('wait', 43),
#              ('hailing', 1),
#              ('taxi', 4),
#              ('signaling', 1),
#              ('traffic', 47),
#              ('blonde', 201),
#              ('hair', 414),
#              ('tube', 61),
#              ('waving', 52),
#              ('arm', 148),
#              ('oncoming', 2),
#              ('brochure', 2),
#              ('train', 108),
#              ('rides', 458),
#              ('magizine', 1),
#              ('book', 77),
#              ('pamphlet', 1),
#              ('rocky', 245),
#              ('run', 369),
#              ('across', 476),
#              ('stones', 9),
#              ('area', 398),
#              ('descends', 11),
#              ('end', 52),
#              ('high', 293),
#              ('diving', 74),
#              ('pool', 692),
#              ('dive', 11),
#              ('window', 138),
#              ('overshirt', 1),
#              ('tank', 77),
#              ('chrome', 1),
#              ('door', 61),
#              ('puts', 34),
#              ('elevator', 7),
#              ('light', 169),
#              ('swim', 97),
#              ('shorts', 377),
#              ('trunks', 95),
#              ('arms', 247),
#              ('outstretched', 38),
#              ('hiker', 80),
#              ('bluff', 5),
#              ('mountains', 204),
#              ('ski', 103),
#              ("'s", 401),
#              ('landscape', 45),
#              ('mountain', 556),
#              ('beautiful', 53),
#              ('pauses', 10),
#              ('mountaintop', 25),
#              ('attempting', 57),
#              ('purple', 312),
#              ('low', 67),
#              ('cut', 32),
#              ('yard', 201),
#              ('frisbee', 337),
#              ('parking', 72),
#              ('lot', 108),
#              ('middle', 163),
#              ('during', 174),
#              ('heavy', 28),
#              ('mat', 22),
#              ('between', 125),
#              ('suv', 14),
#              ('pickup', 4),
#              ('open', 192),
#              ('busy', 100),
#              ('terrain', 36),
#              ('woolly', 1),
#              ('doberman', 17),
#              ('chasing', 184),
#              ('catches', 123),
#              ('tennis', 429),
#              ('multicolor', 11),
#              ('balloons', 28),
#              ('night', 159),
#              ('hot', 29),
#              ('lit', 50),
#              ('lined', 42),
#              ('nighttime', 12),
#              ('helmet', 358),
#              ('bike', 868),
#              ('miniature', 5),
#              ('dirt', 592),
#              ('bicycle', 418),
#              ('race', 382),
#              ('pedals', 3),
#              ('quickly', 30),
#              ('bmx', 77),
#              ('eight', 17),
#              ('gathered', 68),
#              ('dark', 269),
#              ('porch', 24),
#              ('darkened', 10),
#              ('room', 132),
#              ('throwing', 109),
#              ('cleans', 2),
#              ('bubbles', 89),
#              ('suds', 4),
#              ('wiped', 2),
#              ('clean', 7),
#              ('foam', 20),
#              ('ramp', 319),
#              ('soapy', 1),
#              ('getting', 124),
#              ('cleaned', 1),
#              ('slides', 92),
#              ('slide', 302),
#              ('wading', 56),
#              ('toys', 49),
#              ('floating', 38),
#              ('backyard', 67),
#              ('sliding', 123),
#              ('colorful', 218),
#              ('tubes', 2),
#              ('falling', 81),
#              ('wetsuit', 81),
#              ('toddler', 169),
#              ('waiting', 118),
#              ('come', 11),
#              ('so', 17),
#              ('droplets', 7),
#              ('fly', 38),
#              ('throws', 67),
#              ('sticks', 62),
#              ('tongue', 111),
#              ('make', 64),
#              ('faces', 74),
#              ('sticking', 53),
#              ('look', 261),
#              ('silly', 17),
#              ('horse', 233),
#              ('sweatshirt', 78),
#              ('fire', 111),
#              ('barrel', 22),
#              ('lead', 17),
#              ('horses', 92),
#              ('contained', 1),
#              ('bulldog', 9),
#              ('sheep', 56),
#              ('boxer', 18),
#              ('pushing', 64),
#              ('anouther', 1),
#              ('skinny', 18),
#              ('smaller', 67),
#              ('int', 6),
#              ('various', 19),
#              ('sizes', 4),
#              ('lady', 223),
#              ('no', 87),
#              ('dock', 93),
#              ('deck', 39),
#              ('closeup', 67),
#              ('that', 397),
#              ('paws', 30),
#              ('lying', 99),
#              ('resting', 44),
#              ('tiled', 9),
#              ('eyes', 92),
#              ('rests', 23),
#              ('patio', 21),
#              ('bricks', 5),
#              ('artificial', 10),
#              ('safety', 32),
#              ('harness', 82),
#              ('indoor', 43),
#              ('rocks', 257),
#              ('ring', 69),
#              ('jumphouse', 1),
#              ('teenage', 72),
#              ('seating', 7),
#              ('inflated', 5),
#              ('family', 86),
#              ('tractor', 10),
#              ('polaris', 3),
#              ('vehicle', 79),
#              ('played', 19),
#              ('wheeler', 21),
#              ('riding', 907),
#              ('atv', 39),
#              ('costume', 132),
#              ('left', 90),
#              ('sequined', 4),
#              ('feather', 12),
#              ('sidewalk', 375),
#              ('salmon', 2),
#              ('bikini', 66),
#              ('outfit', 159),
#              ('drinking', 100),
#              ('pop', 7),
#              ('approached', 2),
#              ('flamboyant', 3),
#              ('dressed', 570),
#              ('feathered', 8),
#              ('headress', 1),
#              ('skiiers', 9),
#              ('forest', 160),
#              ('skiing', 115),
#              ('wooded', 101),
#              ('cross', 74),
#              ('country', 36),
#              ('skiers', 36),
#              ('woodland', 21),
#              ('trail', 146),
#              ('woods', 211),
#              ('hikers', 35),
#              ('pathway', 12),
#              ('path', 325),
#              ('happily', 26),
#              ('energetic', 1),
#              ('mother', 43),
#              ('boardwalk', 24),
#              ('sea', 30),
#              ('pier', 34),
#              ('evening', 9),
#              ('pony', 13),
#              ('wintertime', 2),
#              ('atop', 37),
#              ('draft', 3),
#              ('n', 2),
#              ('daft', 1),
#              ('pull', 32),
#              ('cart', 89),
#              ('golden', 110),
#              ('sleigh', 4),
#              ('driven', 10),
#              ('coat', 269),
#              ('pulling', 110),
#              ('carriage', 19),
#              ('sled', 118),
#              ('steered', 2),
#              ('sheer', 16),
#              ('using', 64),
#              ('flat', 14),
#              ('rappels', 2),
#              ('steep', 62),
#              ('incline', 11),
#              ('vest', 98),
#              ('inside', 174),
#              ('dome', 3),
#              ('shaft', 2),
#              ('cave', 21),
#              ('shows', 33),
#              ('spelunkers', 2),
#              ('cavern', 1),
#              ('bathed', 1),
#              ('sunlight', 11),
#              ('backpackers', 2),
#              ('lay', 24),
#              ('dry', 79),
#              ('camp', 6),
#              ('gear', 117),
#              ('chalk', 17),
#              ('portrait', 7),
#              ('stream', 111),
#              ('drawing', 13),
#              ('barn', 13),
#              ('like', 104),
#              ('elaborate', 11),
#              ('illustration', 2),
#              ('deep', 88),
#              ('pile', 76),
#              ('fountain', 181),
#              ('fountains', 14),
#              ('sprayed', 25),
#              ('corgi', 7),
#              ('tunnel', 67),
#              ('course', 135),
#              ('obstacle', 125),
#              ('obedience', 3),
#              ('swimsuit', 61),
#              ('handrail', 33),
#              ('bathing', 119),
#              ('suit', 249),
#              ('spray', 37),
#              ('soaked', 12),
#              ('jet', 23),
#              ('shower', 20),
#              ('gets', 107),
#              ('underwater', 53),
#              ('headed', 16),
#              ('swims', 104),
#              ('gun', 41),
#              ('foot', 44),
#              ('aims', 5),
#              ('fireplace', 11),
#              ('new', 17),
#              ('pointed', 13),
#              ('alone', 35),
#              ('jagged', 7),
#              ('snowmobile', 13),
#              ('mid', 30),
#              ('snowmobiler', 2),
#              ('flies', 104),
#              ('rider', 185),
#              ('or', 87),
#              ('machine', 31),
#              ('pine', 23),
#              ('rural', 45),
#              ('snowmobiles', 4),
#              ('helmets', 39),
#              ('goggles', 73),
#              ('snowmobiling', 2),
#              ('helmeted', 15),
#              ('drive', 16),
#              ('atvs', 3),
#              ('heads', 49),
#              ('wheel', 66),
#              ('wheelers', 3),
#              ('empty', 50),
#              ('all', 140),
#              ('gin', 1),
#              ('airborne', 75),
#              ('quad', 6),
#              ('harvested', 2),
#              ('cornfield', 1),
#              ('s', 3),
#              ('happy', 20),
#              ('od', 1),
#              ('playfully', 32),
#              ('soccer', 580),
#              ('tucked', 1),
#              ('t', 166),
#              ('artist', 14),
#              ('paints', 12),
#              ('clouds', 32),
#              ('braids', 6),
#              ('colors', 22),
#              ('paper', 79),
#              ('cyclist', 72),
#              ('curved', 4),
#              ('aerodynamic', 2),
#              ('sharp', 21),
#              ('curve', 24),
#              ('pedaling', 3),
#              ('cows', 13),
#              ('graze', 2),
#              ('biker', 171),
#              ('fetch', 31),
#              ('pounces', 8),
#              ('cine', 1),
#              ('old', 174),
#              ('fashioned', 8),
#              ('video', 40),
#              ('steadies', 2),
#              ('aim', 4),
#              ('rosy', 1),
#              ('cheeks', 6),
#              ('lips', 17),
#              ('border', 9),
#              ('collie', 30),
#              ('audience', 38),
#              ('dug', 3),
#              ('watch', 240),
#              ('agile', 1),
#              ('onlookers', 52),
#              ('closely', 5),
#              ('smooth', 6),
#              ('stacking', 1),
#              ('against', 201),
#              ('backdrop', 9),
#              ('shoes', 91),
#              ('rappeling', 1),
#              ('headlamp', 2),
#              ('attached', 53),
#              ('snakeskin', 1),
#              ('sprays', 11),
#              ('frog', 5),
#              ('public', 48),
#              ('wood', 73),
#              ('barrior', 1),
#              ('animal', 99),
#              ('bird', 194),
#              ('seeds', 6),
#              ('sunflower', 1),
#              ('clinging', 5),
#              ('finger', 36),
#              ('wades', 12),
#              ('guided', 3),
#              ('laughs', 33),
#              ('playful', 7),
#              ('beige', 55),
#              ('torwards', 1),
#              ('outdoor', 137),
#              ('handstand', 48),
#              ('does', 232),
#              ('sheets', 5),
#              ('upside', 109),
#              ('snowboard', 88),
#              ('surfboard', 146),
#              ('bikes', 87),
#              ('traveling', 16),
#              ('worn', 5),
#              ('motorcycles', 27),
#              ('motorbikes', 7),
#              ('follow', 14),
#              ('garment', 2),
#              ('flag', 98),
#              ('crescent', 1),
#              ('moon', 5),
#              ('star', 13),
#              ('gown', 9),
#              ('muslim', 3),
#              ('helps', 29),
#              ('wave', 317),
#              ('half', 42),
#              ('naked', 52),
#              ('chair', 133),
#              ('older', 226),
#              ('back', 387),
#              ('relaxes', 12),
#              ('adobe', 1),
#              ('where', 40),
#              ('bicycles', 55),
#              ('propped', 4),
#              ('cap', 195),
#              ('close', 55),
#              ('parked', 41),
#              ('relaxing', 15),
#              ('folding', 11),
#              ('topless', 21),
#              ('slippers', 2),
#              ('navy', 14),
#              ('reclining', 2),
#              ('hauling', 1),
#              ('retrieve', 9),
#              ('mouths', 40),
#              ('tug', 44),
#              ('chew', 16),
#              ('haired', 203),
#              ('bottled', 2),
#              ('drink', 108),
#              ('tilted', 4),
#              ('spiked', 4),
#              ('party', 56),
#              ('streets', 28),
#              ('they', 121),
#              ('women', 652),
#              ('parade', 70),
#              ('neck', 49),
#              ('vegetation', 4),
#              ('filled', 52),
#              ('bushes', 37),
#              ('creating', 8),
#              ('splash', 44),
#              ('seaweed', 11),
#              ('lav', 1),
#              ('swimmers', 13),
#              ('kelp', 1),
#              ('foreground', 40),
#              ('sandals', 21),
#              ('short', 75),
#              ('sleeved', 17),
#              ('pinstripe', 2),
#              ('snows', 4),
#              ('furry', 59),
#              ('attempts', 56),
#              ('itself', 20),
#              ('self', 6),
#              ('backpacks', 32),
#              ('placed', 9),
#              ('cardboard', 27),
#              ('bus', 81),
#              ('station', 34),
#              ('bouncing', 29),
#              ('folded', 9),
#              ('beds', 3),
#              ('bedroom', 5),
#              ('snowboarder', 238),
#              ('slope', 76),
#              ('boarders', 1),
#              ('snowboarders', 12),
#              ('slopes', 7),
#              ('clothing', 130),
#              ('store', 111),
#              ('opening', 13),
#              ('stores', 8),
#              ('piece', 66),
#              ('attire', 25),
#              ('car', 429),
#              ('strip', 22),
#              ('boots', 66),
#              ('stepping', 8),
#              ('van', 16),
#              ('wear', 49),
#              ('game', 368),
#              ('plants', 43),
#              ('crossing', 58),
#              ('greenery', 6),
#              ('suspension', 1),
#              ('tropical', 12),
#              ('caution', 6),
#              ('sign', 245),
#              ('beside', 247),
#              ('bright', 124),
#              ('truck', 89),
#              ('others', 171),
#              ('helping', 27),
#              ('step', 30),
#              ('pulled', 39),
#              ('passengers', 8),
#              ('load', 2),
#              ('brightly', 38),
#              ('poses', 142),
#              ('pig', 5),
#              ('hugs', 24),
#              ('who', 216),
#              ('embracing', 8),
#              ('event', 66),
#              ('hugging', 59),
#              ('hooded', 36),
#              ('stretch', 11),
#              ('bicyclist', 64),
#              ('spandex', 3),
#              ('biking', 28),
#              ('jogging', 26),
#              ('headset', 5),
#              ('walkman', 1),
#              ('jogs', 13),
#              ('headphones', 42),
#              ('plant', 16),
#              ('corner', 59),
#              ('bicyclists', 24),
#              ('intersection', 14),
#              ('bikers', 31),
#              ('stop', 36),
#              ('town', 24),
#              ('without', 28),
#              ('guiding', 5),
#              ('wagon', 28),
#              ('escorts', 1),
#              ('leading', 21),
#              ('drawn', 4),
#              ('shetland', 1),
#              ('hits', 49),
#              ...])

# %%
# Create a word count of your tokenizer to visulize the Top 30 occuring words after text processing
word_counts = tokenizer.word_counts
df_word = pd.DataFrame.from_dict(word_counts, orient = 'index')
df_word = df_word.sort_values(by = [0], ascending=False).reset_index()
df_word = df_word.rename(columns={'index':'word', 0:'count'})

words = list(df_word[:30].word)
count =list(df_word['count'][:30])
plthist(list(range(0,30)),words,count, title='Top 30 occuring words after text processing')

# %%
max_len = max([len(cap) for cap in train_seqs])
print("shape of caption vector: ", len(train_seqs))
print("Maximum length of sequence: ",max_len)
# Out:
# shape of caption vector:  40455
# Maximum length of sequence:  39

# %%
# Pad each vector to the max_length of the captions ^ store it to a vairable

cap_vector= tf.keras.preprocessing.sequence.pad_sequences(train_seqs,
                                                          padding='post',
                                                          maxlen=max_len)

print("The shape of Caption vector is :" + str(cap_vector.shape))
# Out:
# The shape of Caption vector is :(40455, 39)

# %%
cap_vector
# Out:
# array([[ 3,  2, 44, ...,  0,  0,  0],
#        [ 3,  2, 20, ...,  0,  0,  0],
#        [ 3,  2, 41, ...,  0,  0,  0],
#        ...,
#        [ 3,  2, 45, ...,  0,  0,  0],
#        [ 3,  2, 86, ...,  0,  0,  0],
#        [ 3,  2, 86, ...,  0,  0,  0]], dtype=int32)

# %% [markdown]
# ## Pre-processing the images
#
# 1.Resize them into the shape of (299, 299)
#
# 3.Normalize the image within the range of -1 to 1, such that it is in correct format for InceptionV3.

# %%
#write your code here
def preprocess_image(image_path, shape = (299, 299)):
    image = tf.io.read_file(image_path)
    image = tf.image.decode_jpeg(image,channels=3)
    image = tf.image.resize(image,shape)
    image = tf.keras.applications.inception_v3.preprocess_input(image)
    return image, image_path

# %%
print("Shape after resize :", preprocess_image(all_img_path[0])[0].shape)
plt.imshow(preprocess_image(all_img_path[0])[0])
# Out:
# Shape after resize : (299, 299, 3)

# %%
encode_train_set = sorted(set(all_img_vector))

image_dataset = tf.data.Dataset.from_tensor_slices(encode_train_set)
image_dataset = image_dataset.map(preprocess_image, num_parallel_calls=tf.data.experimental.AUTOTUNE).batch(32)
image_dataset
# Out:
# <BatchDataset shapes: ((None, 299, 299, 3), (None,)), types: (tf.float32, tf.string)>

# %% [markdown]
# ## Create the train & test data
# 1.Combine both images & captions to create the train & test dataset using tf.data.Dataset API. Create the train-test spliit using 80-20 ratio & random state = 42
#
# 2.Make sure you have done Shuffle and batch while building the dataset
#
# 3.The shape of each image in the dataset after building should be (batch_size, 299, 299, 3)
#
# 4.The shape of each caption in the dataset after building should be(batch_size, max_len)

# %%
# train-test split
image_train, image_test, caption_train, caption_test = train_test_split(all_img_vector,cap_vector,
                                                                        test_size=0.2,random_state=42)

# %%
print("Training data for images: " + str(len(image_train)))
print("Testing data for images: " + str(len(image_test)))
print("Training data for Captions: " + str(len(caption_train)))
print("Testing data for Captions: " + str(len(caption_test)))
# Out:
# Training data for images: 32364
# Testing data for images: 8091
# Training data for Captions: 32364
# Testing data for Captions: 8091

# %%
sample_img_batch, sample_cap_batch = next(iter(image_dataset))
print(sample_img_batch.shape) #(batch_size, 299, 299, 3)
print(sample_cap_batch.shape) #(batch_size, max_len)
# Out:
# (32, 299, 299, 3)
# (32,)

# %% [markdown]
# ## Load the pretrained Imagenet weights of Inception net V3
#
# 1.To save the memory(RAM) from getting exhausted, extract the features of thei mage using the last layer of pre-trained model. Including this as part of training will lead to higher computational time.
#
# 2.The shape of the output of this layer is 8x8x2048.
#
# 3.Use a function to extract the features of each image in the train & test dataset such that the shape of each image should be (batch_size, 8*8, 2048)

# %%
image_model = tf.keras.applications.InceptionV3(include_top=False,weights='imagenet')

image_model = tf.keras.applications.InceptionV3(include_top=False,weights='imagenet')

new_input = image_model.input  # get the input of the image_model
hidden_layer = image_model.layers[-1].output  # get the output of the image_model

image_features_extract_model = keras.Model(new_input, hidden_layer)  # build the final model using both input & output layer
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 0s 0us/step

# %%
image_features_extract_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# conv2d_474 (Conv2D)             (None, None, None, 3 864         input_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_474 (BatchN (None, None, None, 3 96          conv2d_474[0][0]
# __________________________________________________________________________________________________
# activation_470 (Activation)     (None, None, None, 3 0           batch_normalization_474[0][0]
# __________________________________________________________________________________________________
# conv2d_475 (Conv2D)             (None, None, None, 3 9216        activation_470[0][0]
# __________________________________________________________________________________________________
# batch_normalization_475 (BatchN (None, None, None, 3 96          conv2d_475[0][0]
# __________________________________________________________________________________________________
# activation_471 (Activation)     (None, None, None, 3 0           batch_normalization_475[0][0]
# __________________________________________________________________________________________________
# conv2d_476 (Conv2D)             (None, None, None, 6 18432       activation_471[0][0]
# __________________________________________________________________________________________________
# batch_normalization_476 (BatchN (None, None, None, 6 192         conv2d_476[0][0]
# __________________________________________________________________________________________________
# activation_472 (Activation)     (None, None, None, 6 0           batch_normalization_476[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_20 (MaxPooling2D) (None, None, None, 6 0           activation_472[0][0]
# __________________________________________________________________________________________________
# conv2d_477 (Conv2D)             (None, None, None, 8 5120        max_pooling2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_477 (BatchN (None, None, None, 8 240         conv2d_477[0][0]
# __________________________________________________________________________________________________
# activation_473 (Activation)     (None, None, None, 8 0           batch_normalization_477[0][0]
# __________________________________________________________________________________________________
# conv2d_478 (Conv2D)             (None, None, None, 1 138240      activation_473[0][0]
# __________________________________________________________________________________________________
# batch_normalization_478 (BatchN (None, None, None, 1 576         conv2d_478[0][0]
# __________________________________________________________________________________________________
# activation_474 (Activation)     (None, None, None, 1 0           batch_normalization_478[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_21 (MaxPooling2D) (None, None, None, 1 0           activation_474[0][0]
# __________________________________________________________________________________________________
# conv2d_482 (Conv2D)             (None, None, None, 6 12288       max_pooling2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_482 (BatchN (None, None, None, 6 192         conv2d_482[0][0]
# __________________________________________________________________________________________________
# activation_478 (Activation)     (None, None, None, 6 0           batch_normalization_482[0][0]
# __________________________________________________________________________________________________
# conv2d_480 (Conv2D)             (None, None, None, 4 9216        max_pooling2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_483 (Conv2D)             (None, None, None, 9 55296       activation_478[0][0]
# __________________________________________________________________________________________________
# batch_normalization_480 (BatchN (None, None, None, 4 144         conv2d_480[0][0]
# __________________________________________________________________________________________________
# batch_normalization_483 (BatchN (None, None, None, 9 288         conv2d_483[0][0]
# __________________________________________________________________________________________________
# activation_476 (Activation)     (None, None, None, 4 0           batch_normalization_480[0][0]
# __________________________________________________________________________________________________
# activation_479 (Activation)     (None, None, None, 9 0           batch_normalization_483[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_45 (AveragePo (None, None, None, 1 0           max_pooling2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_479 (Conv2D)             (None, None, None, 6 12288       max_pooling2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_481 (Conv2D)             (None, None, None, 6 76800       activation_476[0][0]
# __________________________________________________________________________________________________
# conv2d_484 (Conv2D)             (None, None, None, 9 82944       activation_479[0][0]
# __________________________________________________________________________________________________
# conv2d_485 (Conv2D)             (None, None, None, 3 6144        average_pooling2d_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_479 (BatchN (None, None, None, 6 192         conv2d_479[0][0]
# __________________________________________________________________________________________________
# batch_normalization_481 (BatchN (None, None, None, 6 192         conv2d_481[0][0]
# __________________________________________________________________________________________________
# batch_normalization_484 (BatchN (None, None, None, 9 288         conv2d_484[0][0]
# __________________________________________________________________________________________________
# batch_normalization_485 (BatchN (None, None, None, 3 96          conv2d_485[0][0]
# __________________________________________________________________________________________________
# activation_475 (Activation)     (None, None, None, 6 0           batch_normalization_479[0][0]
# __________________________________________________________________________________________________
# activation_477 (Activation)     (None, None, None, 6 0           batch_normalization_481[0][0]
# __________________________________________________________________________________________________
# activation_480 (Activation)     (None, None, None, 9 0           batch_normalization_484[0][0]
# __________________________________________________________________________________________________
# activation_481 (Activation)     (None, None, None, 3 0           batch_normalization_485[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, None, None, 2 0           activation_475[0][0]
#                                                                  activation_477[0][0]
#                                                                  activation_480[0][0]
#                                                                  activation_481[0][0]
# __________________________________________________________________________________________________
# conv2d_489 (Conv2D)             (None, None, None, 6 16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_489 (BatchN (None, None, None, 6 192         conv2d_489[0][0]
# __________________________________________________________________________________________________
# activation_485 (Activation)     (None, None, None, 6 0           batch_normalization_489[0][0]
# __________________________________________________________________________________________________
# conv2d_487 (Conv2D)             (None, None, None, 4 12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_490 (Conv2D)             (None, None, None, 9 55296       activation_485[0][0]
# __________________________________________________________________________________________________
# batch_normalization_487 (BatchN (None, None, None, 4 144         conv2d_487[0][0]
# __________________________________________________________________________________________________
# batch_normalization_490 (BatchN (None, None, None, 9 288         conv2d_490[0][0]
# __________________________________________________________________________________________________
# activation_483 (Activation)     (None, None, None, 4 0           batch_normalization_487[0][0]
# __________________________________________________________________________________________________
# activation_486 (Activation)     (None, None, None, 9 0           batch_normalization_490[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_46 (AveragePo (None, None, None, 2 0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_486 (Conv2D)             (None, None, None, 6 16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_488 (Conv2D)             (None, None, None, 6 76800       activation_483[0][0]
# __________________________________________________________________________________________________
# conv2d_491 (Conv2D)             (None, None, None, 9 82944       activation_486[0][0]
# __________________________________________________________________________________________________
# conv2d_492 (Conv2D)             (None, None, None, 6 16384       average_pooling2d_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_486 (BatchN (None, None, None, 6 192         conv2d_486[0][0]
# __________________________________________________________________________________________________
# batch_normalization_488 (BatchN (None, None, None, 6 192         conv2d_488[0][0]
# __________________________________________________________________________________________________
# batch_normalization_491 (BatchN (None, None, None, 9 288         conv2d_491[0][0]
# __________________________________________________________________________________________________
# batch_normalization_492 (BatchN (None, None, None, 6 192         conv2d_492[0][0]
# __________________________________________________________________________________________________
# activation_482 (Activation)     (None, None, None, 6 0           batch_normalization_486[0][0]
# __________________________________________________________________________________________________
# activation_484 (Activation)     (None, None, None, 6 0           batch_normalization_488[0][0]
# __________________________________________________________________________________________________
# activation_487 (Activation)     (None, None, None, 9 0           batch_normalization_491[0][0]
# __________________________________________________________________________________________________
# activation_488 (Activation)     (None, None, None, 6 0           batch_normalization_492[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, None, None, 2 0           activation_482[0][0]
#                                                                  activation_484[0][0]
#                                                                  activation_487[0][0]
#                                                                  activation_488[0][0]
# __________________________________________________________________________________________________
# conv2d_496 (Conv2D)             (None, None, None, 6 18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_496 (BatchN (None, None, None, 6 192         conv2d_496[0][0]
# __________________________________________________________________________________________________
# activation_492 (Activation)     (None, None, None, 6 0           batch_normalization_496[0][0]
# __________________________________________________________________________________________________
# conv2d_494 (Conv2D)             (None, None, None, 4 13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_497 (Conv2D)             (None, None, None, 9 55296       activation_492[0][0]
# __________________________________________________________________________________________________
# batch_normalization_494 (BatchN (None, None, None, 4 144         conv2d_494[0][0]
# __________________________________________________________________________________________________
# batch_normalization_497 (BatchN (None, None, None, 9 288         conv2d_497[0][0]
# __________________________________________________________________________________________________
# activation_490 (Activation)     (None, None, None, 4 0           batch_normalization_494[0][0]
# __________________________________________________________________________________________________
# activation_493 (Activation)     (None, None, None, 9 0           batch_normalization_497[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_47 (AveragePo (None, None, None, 2 0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_493 (Conv2D)             (None, None, None, 6 18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_495 (Conv2D)             (None, None, None, 6 76800       activation_490[0][0]
# __________________________________________________________________________________________________
# conv2d_498 (Conv2D)             (None, None, None, 9 82944       activation_493[0][0]
# __________________________________________________________________________________________________
# conv2d_499 (Conv2D)             (None, None, None, 6 18432       average_pooling2d_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_493 (BatchN (None, None, None, 6 192         conv2d_493[0][0]
# __________________________________________________________________________________________________
# batch_normalization_495 (BatchN (None, None, None, 6 192         conv2d_495[0][0]
# __________________________________________________________________________________________________
# batch_normalization_498 (BatchN (None, None, None, 9 288         conv2d_498[0][0]
# __________________________________________________________________________________________________
# batch_normalization_499 (BatchN (None, None, None, 6 192         conv2d_499[0][0]
# __________________________________________________________________________________________________
# activation_489 (Activation)     (None, None, None, 6 0           batch_normalization_493[0][0]
# __________________________________________________________________________________________________
# activation_491 (Activation)     (None, None, None, 6 0           batch_normalization_495[0][0]
# __________________________________________________________________________________________________
# activation_494 (Activation)     (None, None, None, 9 0           batch_normalization_498[0][0]
# __________________________________________________________________________________________________
# activation_495 (Activation)     (None, None, None, 6 0           batch_normalization_499[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, None, None, 2 0           activation_489[0][0]
#                                                                  activation_491[0][0]
#                                                                  activation_494[0][0]
#                                                                  activation_495[0][0]
# __________________________________________________________________________________________________
# conv2d_501 (Conv2D)             (None, None, None, 6 18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_501 (BatchN (None, None, None, 6 192         conv2d_501[0][0]
# __________________________________________________________________________________________________
# activation_497 (Activation)     (None, None, None, 6 0           batch_normalization_501[0][0]
# __________________________________________________________________________________________________
# conv2d_502 (Conv2D)             (None, None, None, 9 55296       activation_497[0][0]
# __________________________________________________________________________________________________
# batch_normalization_502 (BatchN (None, None, None, 9 288         conv2d_502[0][0]
# __________________________________________________________________________________________________
# activation_498 (Activation)     (None, None, None, 9 0           batch_normalization_502[0][0]
# __________________________________________________________________________________________________
# conv2d_500 (Conv2D)             (None, None, None, 3 995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_503 (Conv2D)             (None, None, None, 9 82944       activation_498[0][0]
# __________________________________________________________________________________________________
# batch_normalization_500 (BatchN (None, None, None, 3 1152        conv2d_500[0][0]
# __________________________________________________________________________________________________
# batch_normalization_503 (BatchN (None, None, None, 9 288         conv2d_503[0][0]
# __________________________________________________________________________________________________
# activation_496 (Activation)     (None, None, None, 3 0           batch_normalization_500[0][0]
# __________________________________________________________________________________________________
# activation_499 (Activation)     (None, None, None, 9 0           batch_normalization_503[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_22 (MaxPooling2D) (None, None, None, 2 0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, None, None, 7 0           activation_496[0][0]
#                                                                  activation_499[0][0]
#                                                                  max_pooling2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_508 (Conv2D)             (None, None, None, 1 98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_508 (BatchN (None, None, None, 1 384         conv2d_508[0][0]
# __________________________________________________________________________________________________
# activation_504 (Activation)     (None, None, None, 1 0           batch_normalization_508[0][0]
# __________________________________________________________________________________________________
# conv2d_509 (Conv2D)             (None, None, None, 1 114688      activation_504[0][0]
# __________________________________________________________________________________________________
# batch_normalization_509 (BatchN (None, None, None, 1 384         conv2d_509[0][0]
# __________________________________________________________________________________________________
# activation_505 (Activation)     (None, None, None, 1 0           batch_normalization_509[0][0]
# __________________________________________________________________________________________________
# conv2d_505 (Conv2D)             (None, None, None, 1 98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_510 (Conv2D)             (None, None, None, 1 114688      activation_505[0][0]
# __________________________________________________________________________________________________
# batch_normalization_505 (BatchN (None, None, None, 1 384         conv2d_505[0][0]
# __________________________________________________________________________________________________
# batch_normalization_510 (BatchN (None, None, None, 1 384         conv2d_510[0][0]
# __________________________________________________________________________________________________
# activation_501 (Activation)     (None, None, None, 1 0           batch_normalization_505[0][0]
# __________________________________________________________________________________________________
# activation_506 (Activation)     (None, None, None, 1 0           batch_normalization_510[0][0]
# __________________________________________________________________________________________________
# conv2d_506 (Conv2D)             (None, None, None, 1 114688      activation_501[0][0]
# __________________________________________________________________________________________________
# conv2d_511 (Conv2D)             (None, None, None, 1 114688      activation_506[0][0]
# __________________________________________________________________________________________________
# batch_normalization_506 (BatchN (None, None, None, 1 384         conv2d_506[0][0]
# __________________________________________________________________________________________________
# batch_normalization_511 (BatchN (None, None, None, 1 384         conv2d_511[0][0]
# __________________________________________________________________________________________________
# activation_502 (Activation)     (None, None, None, 1 0           batch_normalization_506[0][0]
# __________________________________________________________________________________________________
# activation_507 (Activation)     (None, None, None, 1 0           batch_normalization_511[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_48 (AveragePo (None, None, None, 7 0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_504 (Conv2D)             (None, None, None, 1 147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_507 (Conv2D)             (None, None, None, 1 172032      activation_502[0][0]
# __________________________________________________________________________________________________
# conv2d_512 (Conv2D)             (None, None, None, 1 172032      activation_507[0][0]
# __________________________________________________________________________________________________
# conv2d_513 (Conv2D)             (None, None, None, 1 147456      average_pooling2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_504 (BatchN (None, None, None, 1 576         conv2d_504[0][0]
# __________________________________________________________________________________________________
# batch_normalization_507 (BatchN (None, None, None, 1 576         conv2d_507[0][0]
# __________________________________________________________________________________________________
# batch_normalization_512 (BatchN (None, None, None, 1 576         conv2d_512[0][0]
# __________________________________________________________________________________________________
# batch_normalization_513 (BatchN (None, None, None, 1 576         conv2d_513[0][0]
# __________________________________________________________________________________________________
# activation_500 (Activation)     (None, None, None, 1 0           batch_normalization_504[0][0]
# __________________________________________________________________________________________________
# activation_503 (Activation)     (None, None, None, 1 0           batch_normalization_507[0][0]
# __________________________________________________________________________________________________
# activation_508 (Activation)     (None, None, None, 1 0           batch_normalization_512[0][0]
# __________________________________________________________________________________________________
# activation_509 (Activation)     (None, None, None, 1 0           batch_normalization_513[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, None, None, 7 0           activation_500[0][0]
#                                                                  activation_503[0][0]
#                                                                  activation_508[0][0]
#                                                                  activation_509[0][0]
# __________________________________________________________________________________________________
# conv2d_518 (Conv2D)             (None, None, None, 1 122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_518 (BatchN (None, None, None, 1 480         conv2d_518[0][0]
# __________________________________________________________________________________________________
# activation_514 (Activation)     (None, None, None, 1 0           batch_normalization_518[0][0]
# __________________________________________________________________________________________________
# conv2d_519 (Conv2D)             (None, None, None, 1 179200      activation_514[0][0]
# __________________________________________________________________________________________________
# batch_normalization_519 (BatchN (None, None, None, 1 480         conv2d_519[0][0]
# __________________________________________________________________________________________________
# activation_515 (Activation)     (None, None, None, 1 0           batch_normalization_519[0][0]
# __________________________________________________________________________________________________
# conv2d_515 (Conv2D)             (None, None, None, 1 122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_520 (Conv2D)             (None, None, None, 1 179200      activation_515[0][0]
# __________________________________________________________________________________________________
# batch_normalization_515 (BatchN (None, None, None, 1 480         conv2d_515[0][0]
# __________________________________________________________________________________________________
# batch_normalization_520 (BatchN (None, None, None, 1 480         conv2d_520[0][0]
# __________________________________________________________________________________________________
# activation_511 (Activation)     (None, None, None, 1 0           batch_normalization_515[0][0]
# __________________________________________________________________________________________________
# activation_516 (Activation)     (None, None, None, 1 0           batch_normalization_520[0][0]
# __________________________________________________________________________________________________
# conv2d_516 (Conv2D)             (None, None, None, 1 179200      activation_511[0][0]
# __________________________________________________________________________________________________
# conv2d_521 (Conv2D)             (None, None, None, 1 179200      activation_516[0][0]
# __________________________________________________________________________________________________
# batch_normalization_516 (BatchN (None, None, None, 1 480         conv2d_516[0][0]
# __________________________________________________________________________________________________
# batch_normalization_521 (BatchN (None, None, None, 1 480         conv2d_521[0][0]
# __________________________________________________________________________________________________
# activation_512 (Activation)     (None, None, None, 1 0           batch_normalization_516[0][0]
# __________________________________________________________________________________________________
# activation_517 (Activation)     (None, None, None, 1 0           batch_normalization_521[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_49 (AveragePo (None, None, None, 7 0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_514 (Conv2D)             (None, None, None, 1 147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_517 (Conv2D)             (None, None, None, 1 215040      activation_512[0][0]
# __________________________________________________________________________________________________
# conv2d_522 (Conv2D)             (None, None, None, 1 215040      activation_517[0][0]
# __________________________________________________________________________________________________
# conv2d_523 (Conv2D)             (None, None, None, 1 147456      average_pooling2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_514 (BatchN (None, None, None, 1 576         conv2d_514[0][0]
# __________________________________________________________________________________________________
# batch_normalization_517 (BatchN (None, None, None, 1 576         conv2d_517[0][0]
# __________________________________________________________________________________________________
# batch_normalization_522 (BatchN (None, None, None, 1 576         conv2d_522[0][0]
# __________________________________________________________________________________________________
# batch_normalization_523 (BatchN (None, None, None, 1 576         conv2d_523[0][0]
# __________________________________________________________________________________________________
# activation_510 (Activation)     (None, None, None, 1 0           batch_normalization_514[0][0]
# __________________________________________________________________________________________________
# activation_513 (Activation)     (None, None, None, 1 0           batch_normalization_517[0][0]
# __________________________________________________________________________________________________
# activation_518 (Activation)     (None, None, None, 1 0           batch_normalization_522[0][0]
# __________________________________________________________________________________________________
# activation_519 (Activation)     (None, None, None, 1 0           batch_normalization_523[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, None, None, 7 0           activation_510[0][0]
#                                                                  activation_513[0][0]
#                                                                  activation_518[0][0]
#                                                                  activation_519[0][0]
# __________________________________________________________________________________________________
# conv2d_528 (Conv2D)             (None, None, None, 1 122880      mixed5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_528 (BatchN (None, None, None, 1 480         conv2d_528[0][0]
# __________________________________________________________________________________________________
# activation_524 (Activation)     (None, None, None, 1 0           batch_normalization_528[0][0]
# __________________________________________________________________________________________________
# conv2d_529 (Conv2D)             (None, None, None, 1 179200      activation_524[0][0]
# __________________________________________________________________________________________________
# batch_normalization_529 (BatchN (None, None, None, 1 480         conv2d_529[0][0]
# __________________________________________________________________________________________________
# activation_525 (Activation)     (None, None, None, 1 0           batch_normalization_529[0][0]
# __________________________________________________________________________________________________
# conv2d_525 (Conv2D)             (None, None, None, 1 122880      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_530 (Conv2D)             (None, None, None, 1 179200      activation_525[0][0]
# __________________________________________________________________________________________________
# batch_normalization_525 (BatchN (None, None, None, 1 480         conv2d_525[0][0]
# __________________________________________________________________________________________________
# batch_normalization_530 (BatchN (None, None, None, 1 480         conv2d_530[0][0]
# __________________________________________________________________________________________________
# activation_521 (Activation)     (None, None, None, 1 0           batch_normalization_525[0][0]
# __________________________________________________________________________________________________
# activation_526 (Activation)     (None, None, None, 1 0           batch_normalization_530[0][0]
# __________________________________________________________________________________________________
# conv2d_526 (Conv2D)             (None, None, None, 1 179200      activation_521[0][0]
# __________________________________________________________________________________________________
# conv2d_531 (Conv2D)             (None, None, None, 1 179200      activation_526[0][0]
# __________________________________________________________________________________________________
# batch_normalization_526 (BatchN (None, None, None, 1 480         conv2d_526[0][0]
# __________________________________________________________________________________________________
# batch_normalization_531 (BatchN (None, None, None, 1 480         conv2d_531[0][0]
# __________________________________________________________________________________________________
# activation_522 (Activation)     (None, None, None, 1 0           batch_normalization_526[0][0]
# __________________________________________________________________________________________________
# activation_527 (Activation)     (None, None, None, 1 0           batch_normalization_531[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_50 (AveragePo (None, None, None, 7 0           mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_524 (Conv2D)             (None, None, None, 1 147456      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_527 (Conv2D)             (None, None, None, 1 215040      activation_522[0][0]
# __________________________________________________________________________________________________
# conv2d_532 (Conv2D)             (None, None, None, 1 215040      activation_527[0][0]
# __________________________________________________________________________________________________
# conv2d_533 (Conv2D)             (None, None, None, 1 147456      average_pooling2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_524 (BatchN (None, None, None, 1 576         conv2d_524[0][0]
# __________________________________________________________________________________________________
# batch_normalization_527 (BatchN (None, None, None, 1 576         conv2d_527[0][0]
# __________________________________________________________________________________________________
# batch_normalization_532 (BatchN (None, None, None, 1 576         conv2d_532[0][0]
# __________________________________________________________________________________________________
# batch_normalization_533 (BatchN (None, None, None, 1 576         conv2d_533[0][0]
# __________________________________________________________________________________________________
# activation_520 (Activation)     (None, None, None, 1 0           batch_normalization_524[0][0]
# __________________________________________________________________________________________________
# activation_523 (Activation)     (None, None, None, 1 0           batch_normalization_527[0][0]
# __________________________________________________________________________________________________
# activation_528 (Activation)     (None, None, None, 1 0           batch_normalization_532[0][0]
# __________________________________________________________________________________________________
# activation_529 (Activation)     (None, None, None, 1 0           batch_normalization_533[0][0]
# __________________________________________________________________________________________________
# mixed6 (Concatenate)            (None, None, None, 7 0           activation_520[0][0]
#                                                                  activation_523[0][0]
#                                                                  activation_528[0][0]
#                                                                  activation_529[0][0]
# __________________________________________________________________________________________________
# conv2d_538 (Conv2D)             (None, None, None, 1 147456      mixed6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_538 (BatchN (None, None, None, 1 576         conv2d_538[0][0]
# __________________________________________________________________________________________________
# activation_534 (Activation)     (None, None, None, 1 0           batch_normalization_538[0][0]
# __________________________________________________________________________________________________
# conv2d_539 (Conv2D)             (None, None, None, 1 258048      activation_534[0][0]
# __________________________________________________________________________________________________
# batch_normalization_539 (BatchN (None, None, None, 1 576         conv2d_539[0][0]
# __________________________________________________________________________________________________
# activation_535 (Activation)     (None, None, None, 1 0           batch_normalization_539[0][0]
# __________________________________________________________________________________________________
# conv2d_535 (Conv2D)             (None, None, None, 1 147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_540 (Conv2D)             (None, None, None, 1 258048      activation_535[0][0]
# __________________________________________________________________________________________________
# batch_normalization_535 (BatchN (None, None, None, 1 576         conv2d_535[0][0]
# __________________________________________________________________________________________________
# batch_normalization_540 (BatchN (None, None, None, 1 576         conv2d_540[0][0]
# __________________________________________________________________________________________________
# activation_531 (Activation)     (None, None, None, 1 0           batch_normalization_535[0][0]
# __________________________________________________________________________________________________
# activation_536 (Activation)     (None, None, None, 1 0           batch_normalization_540[0][0]
# __________________________________________________________________________________________________
# conv2d_536 (Conv2D)             (None, None, None, 1 258048      activation_531[0][0]
# __________________________________________________________________________________________________
# conv2d_541 (Conv2D)             (None, None, None, 1 258048      activation_536[0][0]
# __________________________________________________________________________________________________
# batch_normalization_536 (BatchN (None, None, None, 1 576         conv2d_536[0][0]
# __________________________________________________________________________________________________
# batch_normalization_541 (BatchN (None, None, None, 1 576         conv2d_541[0][0]
# __________________________________________________________________________________________________
# activation_532 (Activation)     (None, None, None, 1 0           batch_normalization_536[0][0]
# __________________________________________________________________________________________________
# activation_537 (Activation)     (None, None, None, 1 0           batch_normalization_541[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_51 (AveragePo (None, None, None, 7 0           mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_534 (Conv2D)             (None, None, None, 1 147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_537 (Conv2D)             (None, None, None, 1 258048      activation_532[0][0]
# __________________________________________________________________________________________________
# conv2d_542 (Conv2D)             (None, None, None, 1 258048      activation_537[0][0]
# __________________________________________________________________________________________________
# conv2d_543 (Conv2D)             (None, None, None, 1 147456      average_pooling2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_534 (BatchN (None, None, None, 1 576         conv2d_534[0][0]
# __________________________________________________________________________________________________
# batch_normalization_537 (BatchN (None, None, None, 1 576         conv2d_537[0][0]
# __________________________________________________________________________________________________
# batch_normalization_542 (BatchN (None, None, None, 1 576         conv2d_542[0][0]
# __________________________________________________________________________________________________
# batch_normalization_543 (BatchN (None, None, None, 1 576         conv2d_543[0][0]
# __________________________________________________________________________________________________
# activation_530 (Activation)     (None, None, None, 1 0           batch_normalization_534[0][0]
# __________________________________________________________________________________________________
# activation_533 (Activation)     (None, None, None, 1 0           batch_normalization_537[0][0]
# __________________________________________________________________________________________________
# activation_538 (Activation)     (None, None, None, 1 0           batch_normalization_542[0][0]
# __________________________________________________________________________________________________
# activation_539 (Activation)     (None, None, None, 1 0           batch_normalization_543[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, None, None, 7 0           activation_530[0][0]
#                                                                  activation_533[0][0]
#                                                                  activation_538[0][0]
#                                                                  activation_539[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# batch_normalization_548 (BatchN (None, None, None, 1 576         conv2d_548[0][0]
# __________________________________________________________________________________________________
# activation_540 (Activation)     (None, None, None, 1 0           batch_normalization_544[0][0]
# __________________________________________________________________________________________________
# activation_544 (Activation)     (None, None, None, 1 0           batch_normalization_548[0][0]
# __________________________________________________________________________________________________
# conv2d_545 (Conv2D)             (None, None, None, 3 552960      activation_540[0][0]
# __________________________________________________________________________________________________
# conv2d_549 (Conv2D)             (None, None, None, 1 331776      activation_544[0][0]
# __________________________________________________________________________________________________
# batch_normalization_545 (BatchN (None, None, None, 3 960         conv2d_545[0][0]
# __________________________________________________________________________________________________
# batch_normalization_549 (BatchN (None, None, None, 1 576         conv2d_549[0][0]
# __________________________________________________________________________________________________
# activation_541 (Activation)     (None, None, None, 3 0           batch_normalization_545[0][0]
# __________________________________________________________________________________________________
# activation_545 (Activation)     (None, None, None, 1 0           batch_normalization_549[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_23 (MaxPooling2D) (None, None, None, 7 0           mixed7[0][0]
# __________________________________________________________________________________________________
# mixed8 (Concatenate)            (None, None, None, 1 0           activation_541[0][0]
#                                                                  activation_545[0][0]
#                                                                  max_pooling2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_554 (Conv2D)             (None, None, None, 4 573440      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_554 (BatchN (None, None, None, 4 1344        conv2d_554[0][0]
# __________________________________________________________________________________________________
# activation_550 (Activation)     (None, None, None, 4 0           batch_normalization_554[0][0]
# __________________________________________________________________________________________________
# conv2d_551 (Conv2D)             (None, None, None, 3 491520      mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_555 (Conv2D)             (None, None, None, 3 1548288     activation_550[0][0]
# __________________________________________________________________________________________________
# batch_normalization_551 (BatchN (None, None, None, 3 1152        conv2d_551[0][0]
# __________________________________________________________________________________________________
# batch_normalization_555 (BatchN (None, None, None, 3 1152        conv2d_555[0][0]
# __________________________________________________________________________________________________
# activation_547 (Activation)     (None, None, None, 3 0           batch_normalization_551[0][0]
# __________________________________________________________________________________________________
# activation_551 (Activation)     (None, None, None, 3 0           batch_normalization_555[0][0]
# __________________________________________________________________________________________________
# conv2d_552 (Conv2D)             (None, None, None, 3 442368      activation_547[0][0]
# __________________________________________________________________________________________________
# conv2d_553 (Conv2D)             (None, None, None, 3 442368      activation_547[0][0]
# __________________________________________________________________________________________________
# conv2d_556 (Conv2D)             (None, None, None, 3 442368      activation_551[0][0]
# __________________________________________________________________________________________________
# conv2d_557 (Conv2D)             (None, None, None, 3 442368      activation_551[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_52 (AveragePo (None, None, None, 1 0           mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_550 (Conv2D)             (None, None, None, 3 409600      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_552 (BatchN (None, None, None, 3 1152        conv2d_552[0][0]
# __________________________________________________________________________________________________
# batch_normalization_553 (BatchN (None, None, None, 3 1152        conv2d_553[0][0]
# __________________________________________________________________________________________________
# batch_normalization_556 (BatchN (None, None, None, 3 1152        conv2d_556[0][0]
# __________________________________________________________________________________________________
# batch_normalization_557 (BatchN (None, None, None, 3 1152        conv2d_557[0][0]
# __________________________________________________________________________________________________
# conv2d_558 (Conv2D)             (None, None, None, 1 245760      average_pooling2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_550 (BatchN (None, None, None, 3 960         conv2d_550[0][0]
# __________________________________________________________________________________________________
# activation_548 (Activation)     (None, None, None, 3 0           batch_normalization_552[0][0]
# __________________________________________________________________________________________________
# activation_549 (Activation)     (None, None, None, 3 0           batch_normalization_553[0][0]
# __________________________________________________________________________________________________
# activation_552 (Activation)     (None, None, None, 3 0           batch_normalization_556[0][0]
# __________________________________________________________________________________________________
# activation_553 (Activation)     (None, None, None, 3 0           batch_normalization_557[0][0]
# __________________________________________________________________________________________________
# batch_normalization_558 (BatchN (None, None, None, 1 576         conv2d_558[0][0]
# __________________________________________________________________________________________________
# activation_546 (Activation)     (None, None, None, 3 0           batch_normalization_550[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, None, None, 7 0           activation_548[0][0]
#                                                                  activation_549[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, None, None, 7 0           activation_552[0][0]
#                                                                  activation_553[0][0]
# __________________________________________________________________________________________________
# activation_554 (Activation)     (None, None, None, 1 0           batch_normalization_558[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, None, None, 2 0           activation_546[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate_10[0][0]
#                                                                  activation_554[0][0]
# __________________________________________________________________________________________________
# conv2d_563 (Conv2D)             (None, None, None, 4 917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_563 (BatchN (None, None, None, 4 1344        conv2d_563[0][0]
# __________________________________________________________________________________________________
# activation_559 (Activation)     (None, None, None, 4 0           batch_normalization_563[0][0]
# __________________________________________________________________________________________________
# conv2d_560 (Conv2D)             (None, None, None, 3 786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_564 (Conv2D)             (None, None, None, 3 1548288     activation_559[0][0]
# __________________________________________________________________________________________________
# batch_normalization_560 (BatchN (None, None, None, 3 1152        conv2d_560[0][0]
# __________________________________________________________________________________________________
# batch_normalization_564 (BatchN (None, None, None, 3 1152        conv2d_564[0][0]
# __________________________________________________________________________________________________
# activation_556 (Activation)     (None, None, None, 3 0           batch_normalization_560[0][0]
# __________________________________________________________________________________________________
# activation_560 (Activation)     (None, None, None, 3 0           batch_normalization_564[0][0]
# __________________________________________________________________________________________________
# conv2d_561 (Conv2D)             (None, None, None, 3 442368      activation_556[0][0]
# __________________________________________________________________________________________________
# conv2d_562 (Conv2D)             (None, None, None, 3 442368      activation_556[0][0]
# __________________________________________________________________________________________________
# conv2d_565 (Conv2D)             (None, None, None, 3 442368      activation_560[0][0]
# __________________________________________________________________________________________________
# conv2d_566 (Conv2D)             (None, None, None, 3 442368      activation_560[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_53 (AveragePo (None, None, None, 2 0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_559 (Conv2D)             (None, None, None, 3 655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_561 (BatchN (None, None, None, 3 1152        conv2d_561[0][0]
# __________________________________________________________________________________________________
# batch_normalization_562 (BatchN (None, None, None, 3 1152        conv2d_562[0][0]
# __________________________________________________________________________________________________
# batch_normalization_565 (BatchN (None, None, None, 3 1152        conv2d_565[0][0]
# __________________________________________________________________________________________________
# batch_normalization_566 (BatchN (None, None, None, 3 1152        conv2d_566[0][0]
# __________________________________________________________________________________________________
# conv2d_567 (Conv2D)             (None, None, None, 1 393216      average_pooling2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_559 (BatchN (None, None, None, 3 960         conv2d_559[0][0]
# __________________________________________________________________________________________________
# activation_557 (Activation)     (None, None, None, 3 0           batch_normalization_561[0][0]
# __________________________________________________________________________________________________
# activation_558 (Activation)     (None, None, None, 3 0           batch_normalization_562[0][0]
# __________________________________________________________________________________________________
# activation_561 (Activation)     (None, None, None, 3 0           batch_normalization_565[0][0]
# __________________________________________________________________________________________________
# activation_562 (Activation)     (None, None, None, 3 0           batch_normalization_566[0][0]
# __________________________________________________________________________________________________
# batch_normalization_567 (BatchN (None, None, None, 1 576         conv2d_567[0][0]
# __________________________________________________________________________________________________
# activation_555 (Activation)     (None, None, None, 3 0           batch_normalization_559[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, None, None, 7 0           activation_557[0][0]
#                                                                  activation_558[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, None, None, 7 0           activation_561[0][0]
#                                                                  activation_562[0][0]
# __________________________________________________________________________________________________
# activation_563 (Activation)     (None, None, None, 1 0           batch_normalization_567[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, None, None, 2 0           activation_555[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_11[0][0]
#                                                                  activation_563[0][0]
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 21,768,352
# Non-trainable params: 34,432
# __________________________________________________________________________________________________

# %%
# write your code to extract features from each image in the dataset
feature_dict = {}
for image,path in tqdm(image_dataset):
    batch_features = image_features_extract_model(image)
    batch_features = tf.reshape(batch_features,(batch_features.shape[0], -1, batch_features.shape[3]))
    for batch_f, p in zip(batch_features, path):
        path_of_feature = p.numpy().decode("utf-8")
        feature_dict[path_of_feature] =  batch_f.numpy()
# Out:
# 100%|██████████| 253/253 [01:00<00:00,  4.18it/s]

# %%
def map_function(image_name,capt):
    image_tensor = feature_dict[image_name.decode('utf-8')]
    return image_tensor,capt

# %%
def generate_dataset(images_data, captions_data, BATCH_SIZE =32, BUFFER_SIZE = 1000):
    
    dataset = tf.data.Dataset.from_tensor_slices((images_data, captions_data))
    dataset = dataset.shuffle(BUFFER_SIZE)

    dataset = dataset.map(lambda item1, item2: tf.numpy_function(
          map_function, [item1, item2], [tf.float32, tf.int32]),
          num_parallel_calls=tf.data.experimental.AUTOTUNE).batch(BATCH_SIZE)


    dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
    return dataset

# %%
train_dataset=generate_dataset(image_train,caption_train)
test_dataset=generate_dataset(image_test,caption_test)

# %%
sample_img_batch, sample_cap_batch = next(iter(train_dataset))
print(sample_img_batch.shape)  #(batch_size, 8*8, 2048)
print(sample_cap_batch.shape) #(batch_size,40)
# Out:
# (32, 64, 2048)
# (32, 39)

# %% [markdown]
# ## Model Building
# 1.Set the parameters
#
# 2.Build the Encoder, Attention model & Decoder

# %%
BATCH_SIZE = 32
embedding_dim = 256 
units = 512
vocab_size = 5001 #top 5,000 words +1
train_num_steps = len(image_train) // BATCH_SIZE
test_num_steps = len(image_test) // BATCH_SIZE

# %% [markdown]
# ### Encoder

# %%
class Encoder(Model):
    def __init__(self,embed_dim):
        super(Encoder, self).__init__()
        self.dense = tf.keras.layers.Dense(embed_dim)
        self.dropout = tf.keras.layers.Dropout(0.5)
        
    def call(self, features):
        # extract the features from the image shape: (batch, 8*8, embed_dim)
        features =  self.dense(features) 
        features = tf.nn.relu(features)
        
        return features

# %%
encoder=Encoder(embedding_dim)

# %% [markdown]
# ### Attention model

# %%
class Attention_model(Model):
    def __init__(self, units):
        super(Attention_model, self).__init__()
        self.W1 = tf.keras.layers.Dense(units)
        self.W2 = tf.keras.layers.Dense(units) #build your Dense layer
        self.V = tf.keras.layers.Dense(1) #build your final Dense layer with unit 1
        self.units=units

    def call(self, features, hidden):
        #features shape: (batch_size, 8*8, embedding_dim)
        # hidden shape: (batch_size, hidden_size)
        hidden_with_time_axis = tf.expand_dims(hidden, 1) # Expand the hidden shape to shape: (batch_size, 1, hidden_size)
        score = tf.keras.activations.tanh(self.W1(features) + self.W2(hidden_with_time_axis)) # build your score funciton to shape: (batch_size, 8*8, units)
        attention_weights =  tf.keras.activations.softmax(self.V(score), axis=1) # extract your attention weights with shape: (batch_size, 8*8, 1)
        context_vector = attention_weights * features #shape: create the context vector with shape (batch_size, 8*8,embedding_dim)
        context_vector = tf.reduce_sum(context_vector, axis = 1) # reduce the shape to (batch_size, embedding_dim)
        

        return context_vector, attention_weights

# %% [markdown]
# ### Decoder

# %%
class Decoder(Model):
    def __init__(self, embed_dim, units, vocab_size):
        super(Decoder, self).__init__()
        self.units=units
        self.attention = Attention_model(self.units) #iniitalise your Attention model with units
        self.embed = tf.keras.layers.Embedding(vocab_size, embed_dim, mask_zero =  False) #build your Embedding layer
        self.gru = tf.keras.layers.GRU(self.units,
                                       return_sequences=True,
                                       return_state=True,
                                       recurrent_initializer='glorot_uniform')
        self.d1 = tf.keras.layers.Dense(self.units) #build your Dense layer
        self.d2 = tf.keras.layers.Dense(vocab_size) #build your Dense layer
        self.dropout = tf.keras.layers.Dropout(0.5)
        

    def call(self,x,features, hidden):
        context_vector, attention_weights = self.attention(features, hidden) #create your context vector & attention weights from attention model
        embed =  self.dropout(self.embed(x)) # embed your input to shape: (batch_size, 1, embedding_dim)
        mask = self.embed.compute_mask(x)
        embed = tf.concat([tf.expand_dims(context_vector, 1), embed], axis=-1) # Concatenate your input with the context vector from attention layer. Shape: (batch_size, 1, embedding_dim + embedding_dim)
        output,state = self.gru(embed, mask = mask) # Extract the output & hidden state from GRU layer. Output shape : (batch_size, max_length, hidden_size)
        output = self.d1(output)
        output = tf.reshape(output, (-1, output.shape[2])) # shape : (batch_size * max_length, hidden_size)
        output = self.d2(output) # shape : (batch_size * max_length, vocab_size)
        
        return output,state, attention_weights
    
    def init_state(self, batch_size):
        return tf.zeros((batch_size, self.units))

# %%
decoder=Decoder(embedding_dim, units, vocab_size)

# %%
features=encoder(sample_img_batch)

hidden = decoder.init_state(batch_size=sample_cap_batch.shape[0])
dec_input = tf.expand_dims([tokenizer.word_index['<start>']] * sample_cap_batch.shape[0], 1)

predictions, hidden_out, attention_weights= decoder(dec_input, features, hidden)
print('Feature shape from Encoder: {}'.format(features.shape)) #(batch, 8*8, embed_dim)
print('Predcitions shape from Decoder: {}'.format(predictions.shape)) #(batch,vocab_size)
print('Attention weights shape from Decoder: {}'.format(attention_weights.shape)) #(batch, 8*8, embed_dim)
# Out:
# Feature shape from Encoder: (32, 64, 256)
# Predcitions shape from Decoder: (32, 5001)
# Attention weights shape from Decoder: (32, 64, 1)

# %% [markdown]
# ## Model training & optimization
# 1.Set the optimizer & loss object
#
# 2.Create your checkpoint path
#
# 3.Create your training & testing step functions
#
# 4.Create your loss function for the test dataset

# %%
optimizer = tf.keras.optimizers.Adam() #define the optimizer
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none') #define your loss object

# %%
def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask

    return tf.reduce_mean(loss_)

# %%
checkpoint_path = "./checkpoints/train"
ckpt = tf.train.Checkpoint(encoder=encoder,
                           decoder=decoder,
                           optimizer = optimizer)
ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# %%
start_epoch = 0
if ckpt_manager.latest_checkpoint:
    start_epoch = int(ckpt_manager.latest_checkpoint.split('-')[-1])

# %%
@tf.function
def train_step(img_tensor, target):
    loss = 0
    hidden = decoder.init_state(batch_size=target.shape[0])
    dec_input = tf.expand_dims([tokenizer.word_index['<start>']] * target.shape[0], 1)
    
    with tf.GradientTape() as tape:
        features = encoder(img_tensor)
        for i in range(1, target.shape[1]):
            predictions, hidden, _ = decoder(dec_input, features, hidden)
            loss += loss_function(target[:, i], predictions)
            dec_input = tf.expand_dims(target[:, i], 1)
        avg_loss = (loss/int(target.shape[1]))
        trainable_variables = encoder.trainable_variables + decoder.trainable_variables
        gradients = tape.gradient(loss, trainable_variables)
        optimizer.apply_gradients(zip(gradients, trainable_variables))
        
    return loss, avg_loss

# %%
@tf.function
def test_step(img_tensor, target):
    loss = 0
    hidden = decoder.init_state(batch_size=target.shape[0])
    dec_input = tf.expand_dims([tokenizer.word_index['<start>']] * target.shape[0], 1)

    with tf.GradientTape() as tape:
        features = encoder(img_tensor)

        for i in range(1, target.shape[1]):
            predictions, hidden, _ = decoder(dec_input, features, hidden)
            loss += loss_function(target[:, i], predictions)
            dec_input = tf.expand_dims(target[:, i], 1)

        avg_loss = (loss / int(target.shape[1]))

        trainable_variables = encoder.trainable_variables + decoder.trainable_variables
        gradients = tape.gradient(loss, trainable_variables)
        optimizer.apply_gradients(zip(gradients, trainable_variables))
        
    return loss, avg_loss

# %%
def test_loss_cal(test_dataset):
    total_loss = 0
    
    total_loss = 0
    for (batch, (img_tensor, target)) in enumerate(test_dataset):
        batch_loss, t_loss = test_step(img_tensor, target)
        total_loss += t_loss
    avg_test_loss=total_loss/test_num_steps
    
    return avg_test_loss

# %%
loss_plot = []
test_loss_plot = []
EPOCHS = 15

best_test_loss=100
for epoch in tqdm(range(0, EPOCHS)):
    start = time.time()
    total_loss = 0

    for (batch, (img_tensor, target)) in enumerate(train_dataset):
        batch_loss, t_loss = train_step(img_tensor, target)
        total_loss += t_loss
        avg_train_loss=total_loss / train_num_steps
        
    loss_plot.append(avg_train_loss)    
    test_loss = test_loss_cal(test_dataset)
    test_loss_plot.append(test_loss)
    
    print ('For epoch: {}, the train loss is {:.3f}, & test loss is {:.3f}'.format(epoch+1,avg_train_loss,test_loss))
    print ('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
    
    if test_loss < best_test_loss:
        print('Test loss has been reduced from %.3f to %.3f' % (best_test_loss, test_loss))
        best_test_loss = test_loss
        ckpt_manager.save()
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# For epoch: 1, the train loss is 1.187, & test loss is 1.005
# Time taken for 1 epoch 285.1781802177429 sec
#
# Test loss has been reduced from 100.000 to 1.005
#  13%|█▎        | 2/15 [07:04<43:14, 199.58s/it]
# For epoch: 2, the train loss is 0.932, & test loss is 0.893
# Time taken for 1 epoch 139.34085202217102 sec
#
# Test loss has been reduced from 1.005 to 0.893
#  20%|██        | 3/15 [09:24<34:27, 172.33s/it]
# For epoch: 3, the train loss is 0.850, & test loss is 0.826
# Time taken for 1 epoch 139.76258945465088 sec
#
# Test loss has been reduced from 0.893 to 0.826
#  27%|██▋       | 4/15 [11:43<29:11, 159.20s/it]
# For epoch: 4, the train loss is 0.791, & test loss is 0.771
# Time taken for 1 epoch 138.92036414146423 sec
#
# Test loss has been reduced from 0.826 to 0.771
#  33%|███▎      | 5/15 [14:02<25:16, 151.68s/it]
# For epoch: 5, the train loss is 0.742, & test loss is 0.725
# Time taken for 1 epoch 138.2189610004425 sec
#
# Test loss has been reduced from 0.771 to 0.725
#  40%|████      | 6/15 [16:21<22:07, 147.45s/it]
# For epoch: 6, the train loss is 0.701, & test loss is 0.685
# Time taken for 1 epoch 139.0733778476715 sec
#
# Test loss has been reduced from 0.725 to 0.685
#  47%|████▋     | 7/15 [18:40<19:16, 144.54s/it]
# For epoch: 7, the train loss is 0.660, & test loss is 0.646
# Time taken for 1 epoch 138.39004707336426 sec
#
# Test loss has been reduced from 0.685 to 0.646
#  53%|█████▎    | 8/15 [20:58<16:38, 142.70s/it]
# For epoch: 8, the train loss is 0.624, & test loss is 0.612
# Time taken for 1 epoch 138.60561156272888 sec
#
# Test loss has been reduced from 0.646 to 0.612
#  60%|██████    | 9/15 [23:17<14:08, 141.38s/it]
# For epoch: 9, the train loss is 0.592, & test loss is 0.580
# Time taken for 1 epoch 138.307963848114 sec
#
# Test loss has been reduced from 0.612 to 0.580
#  67%|██████▋   | 10/15 [25:35<11:41, 140.29s/it]
# For epoch: 10, the train loss is 0.563, & test loss is 0.552
# Time taken for 1 epoch 137.68951296806335 sec
#
# Test loss has been reduced from 0.580 to 0.552
#  73%|███████▎  | 11/15 [27:53<09:18, 139.57s/it]
# For epoch: 11, the train loss is 0.535, & test loss is 0.525
# Time taken for 1 epoch 137.7727997303009 sec
#
# Test loss has been reduced from 0.552 to 0.525
#  80%|████████  | 12/15 [30:10<06:56, 138.94s/it]
# For epoch: 12, the train loss is 0.511, & test loss is 0.501
# Time taken for 1 epoch 137.34977531433105 sec
#
# Test loss has been reduced from 0.525 to 0.501
#  87%|████████▋ | 13/15 [32:28<04:37, 138.55s/it]
# For epoch: 13, the train loss is 0.488, & test loss is 0.479
# Time taken for 1 epoch 137.4994626045227 sec
#
# Test loss has been reduced from 0.501 to 0.479
# For epoch: 14, the train loss is 0.467, & test loss is 0.461
# Time taken for 1 epoch 138.34397077560425 sec
#
# Test loss has been reduced from 0.479 to 0.461
# 100%|██████████| 15/15 [37:04<00:00, 148.32s/it]
# For epoch: 15, the train loss is 0.447, & test loss is 0.440
# Time taken for 1 epoch 137.834392786026 sec
#
# Test loss has been reduced from 0.461 to 0.440

# %%
plt.plot(loss_plot)
plt.plot(test_loss_plot)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Plot')
plt.legend(["Train", "Test"], loc ="best")
plt.show()

# %% [markdown]
# ## Model Evaluation
# 1.Define your evaluation function using beam search
#
# 2.Test it on a sample data using BLEU score

# %% [markdown]
# ### Beam Search

# %%
def beam_evaluate(image, beam_index = 3):
    max_length=max_len
    start = [tokenizer.word_index['<start>']]
    result = [[start, 0.0]]

    attention_plot = np.zeros((max_length, attention_features_shape))

    hidden = decoder.init_state(batch_size=1)

    temp_input = tf.expand_dims(preprocess_image(image)[0], 0)
    img_tensor_val = image_features_extract_model(temp_input)
    img_tensor_val = tf.reshape(img_tensor_val, (img_tensor_val.shape[0], -1, img_tensor_val.shape[3]))

    features = encoder(img_tensor_val)

    dec_input = tf.expand_dims([tokenizer.word_index['<start>']], 0)

    while len(result[0][0]) < max_length:
        i=0
        temp = []
        for s in result:
            predictions, hidden, attention_weights = decoder(dec_input, features, hidden)
            attention_plot[i] = tf.reshape(attention_weights, (-1, )).numpy()
            i=i+1
            word_preds = np.argsort(predictions[0])[-beam_index:]
          
            for w in word_preds:
                next_cap, prob = s[0][:], s[1]
                next_cap.append(w)
            
                prob += np.log(predictions[0][w])
                    
                temp.append([next_cap, prob])
        result = temp
        result = sorted(result, reverse=False, key=lambda l: l[1])
        result = result[-beam_index:]
        
        
        predicted_id = result[-1]
        pred_list = predicted_id[0]
        
        prd_id = pred_list[-1] 
        if(prd_id!=3):
            dec_input = tf.expand_dims([prd_id], 0)  
        else:
            break
    
    
    result2 = result[-1][0]
    
    intermediate_caption = [tokenizer.index_word[i] for i in result2]
    final_caption = []
    for i in intermediate_caption:
        if i != '<end>':
            final_caption.append(i)
            
        else:
            break

    attention_plot = attention_plot[:len(result), :]
    final_caption = ' '.join(final_caption[1:])
    return final_caption

# %%
def plot_attmap(caption, weights, image):

    fig = plt.figure(figsize=(10, 10))
    temp_img = np.array(Image.open(image))
    
    len_cap = len(caption)
    for cap in range(len_cap):
        weights_img = np.reshape(weights[cap], (8,8))
        weights_img = np.array(Image.fromarray(weights_img).resize((224, 224), Image.LANCZOS))
        
        ax = fig.add_subplot(len_cap//2, len_cap//2, cap+1)
        ax.set_title(caption[cap], fontsize=15)
        
        img=ax.imshow(temp_img)
        
        ax.imshow(weights_img, cmap='gist_heat', alpha=0.6,extent=img.get_extent())
        ax.axis('off')
    plt.subplots_adjust(hspace=0.2, wspace=0.2)
    plt.show()

# %%
from nltk.translate.bleu_score import sentence_bleu

# %%
def filt_text(text):
    filt=['<start>','<unk>','<end>'] 
    temp= text.split()
    [temp.remove(j) for k in filt for j in temp if k==j]
    text=' '.join(temp)
    return text

# %%
features_shape = batch_f.shape[1]
attention_features_shape = batch_f.shape[0]

# %%
rid = np.random.randint(0, len(image_test))
test_image = image_test[rid]
# test_image = './images/413231421_43833a11f5.jpg'
# real_caption = '<start> black dog is digging in the snow <end>'

real_caption = ' '.join([tokenizer.index_word[i] for i in caption_test[rid] if i not in [0]])
result, attention_plot,pred_test = evaluate(test_image)
real_caption=filt_text(real_caption)      
pred_caption=' '.join(result).rsplit(' ', 1)[0]

real_appn = []
real_appn.append(real_caption.split())
reference = real_appn
candidate = pred_caption.split()

print ('Real Caption      :', real_caption)
print ('Prediction Caption:', pred_caption)
print ('')
plot_attmap(result, attention_plot, test_image)

Image.open(test_image)
# Out:
# Real Caption      : a white and brown dog is leaping through the air
# Prediction Caption: a white and brown dog is jumping through the air
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x375 at 0x7F245EC422D0>

# %%
print ('Real Caption      :', real_caption)
print ('Prediction Caption:', pred_caption)

score1 = sentence_bleu(reference, candidate, weights=(1,0,0,0))
score2 = sentence_bleu(reference, candidate, weights=(0,1,0,0))
score3 = sentence_bleu(reference, candidate, weights=(0,0,1,0))
score4 = sentence_bleu(reference, candidate, weights=(0,0,0,1))

print("\nBELU score: ")
print(f"Individual 1-gram: {score1*100}")
print(f"Individual 2-gram: {score2*100}")
print(f"Individual 3-gram: {score3*100}")
print(f"Individual 4-gram: {score4*100}")
# Out:
# Real Caption      : a white and brown dog is leaping through the air
# Prediction Caption: a white and brown dog is jumping through the air
#
# BELU score:
# Individual 1-gram: 90.0
# Individual 2-gram: 77.77777777777779
# Individual 3-gram: 62.5
# Individual 4-gram: 42.857142857142854

# %%
score1 = sentence_bleu(reference, candidate, weights=(1,0,0,0))
score2 = sentence_bleu(reference, candidate, weights=(0.5, 0.5, 0, 0))
score3 = sentence_bleu(reference, candidate, weights=(0.33,0.33,0.33,0))
score4 = sentence_bleu(reference, candidate, weights=(0.25,0.25,0.25,0.25))

print(f"BELU score: ")
print(f"Cumumlative 1-gram: {score1*100}")
print(f"Cumumlative 2-gram: {score2*100}")
print(f"Cumumlative 3-gram: {score3*100}")
print(f"Cumumlative 4-gram: {score4*100}")
# Out:
# BELU score:
# Cumumlative 1-gram: 90.0
# Cumumlative 2-gram: 83.66600265340756
# Cumumlative 3-gram: 76.12420303686652
# Cumumlative 4-gram: 65.80370064762462

# %%
captions=beam_evaluate(test_image)
print(captions)
# Out:
# a dog and brown spots is jumping through the grass

# %%
# install required library
# !pip install gTTS
# Out:
# Collecting gTTS
#   Downloading gTTS-2.2.4-py3-none-any.whl (26 kB)
# Requirement already satisfied: click in /opt/conda/lib/python3.7/site-packages (from gTTS) (7.1.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (from gTTS) (2.25.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from gTTS) (1.15.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->gTTS) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->gTTS) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->gTTS) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests->gTTS) (1.26.3)
# Installing collected packages: gTTS
# Successfully installed gTTS-2.2.4

# %%
# converting text-to-speach 
from gtts import gTTS
from IPython import display

tts = gTTS(pred_caption, slow = False)
tts.save('pred_caption.mp3')

sound_file = 'pred_caption.mp3'
display.display(display.Audio(sound_file))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# converting text-to-speach using beam_search
tts = gTTS(captions, slow = False)
tts.save('beam_evaluate.mp3')

sound_file = 'beam_evaluate.mp3'
display.display(display.Audio(sound_file))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
